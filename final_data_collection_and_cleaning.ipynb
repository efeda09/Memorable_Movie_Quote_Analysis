# %% [markdown]
# **Collecting and Cleaning the Data**

# %% [markdown]
# First, we will import memorable_quotes.txt from the Cornell Movie Quotes Corpus and convert the information we want as a dataframe.

# %%
import pandas as pd

columns = ["movie_title", "memorable_quote", "LINE_ID_MEMORABLE_MATCHED_QUOTE"]
with open("/content/moviequotes.memorable_quotes.txt", "r",
          encoding="latin-1") as file:
    text = file.read()
chunks = text.strip().split("\n\n")
data = [chunk.split("\n") for chunk in chunks]

df_memorable = pd.DataFrame(data, columns = columns)

# %% [markdown]
# Next we will import scripts.txt so that we can merge by line_id to get the characters that say their corresponding line.

# %%
df_memorable["line_id"] = df_memorable["LINE_ID_MEMORABLE_MATCHED_QUOTE"].str.split(" ").str[0]
df_memorable["line_id"] = df_memorable["line_id"].astype(int)
df_memorable = df_memorable[["movie_title", "memorable_quote", "line_id"]]

# %%
columns = ["line_id", "movie_title", "movie_line_nr", "character",
           "reply_to_line_id", "text"]

# read in file as df
df_full = pd.read_csv("moviequotes.scripts.txt", delimiter=r" \+\+\+\$\+\+\+ ",
                      engine="python", header=None, names=columns,
                      encoding="ISO-8859-1")

# %%
df_full = df_full[df_full["line_id"].isin(df_memorable["line_id"])]
df_full = df_full[["line_id", "character"]]
df_full
# Out:
#         line_id character
# 733         733       kat
# 788         788       kat
# 831         831    bianca
# 876         876   michael
# 979         979    walter
# ...         ...       ...
# 892829   893074    keenan
# 893222   893467    sydney
# 893951   894196    storey
# 894001   894246  pulleine
# 894013   894258  crealock
#
# [6280 rows x 2 columns]

# %%
df = df_memorable.merge(df_full, on=("line_id"))

# %%
#putting a separator (_) between quotes said by same character
df_joined = df.groupby(["movie_title", "character"], as_index=False).agg({
    "memorable_quote": "_".join
})
df_joined.to_csv("memorable_quotes.csv")

# %% [markdown]
# Installing Cinemagoer to find imdb IDs of movies

# %%
pip install cinemagoer
# Out:
# Requirement already satisfied: cinemagoer in /usr/local/lib/python3.11/dist-packages (2023.5.1)
# Requirement already satisfied: SQLAlchemy in /usr/local/lib/python3.11/dist-packages (from cinemagoer) (2.0.39)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from cinemagoer) (5.3.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy->cinemagoer) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy->cinemagoer) (4.12.2)

# %%
df_memorable = pd.read_csv("memorable_quotes.csv")
df_memorable
# Out:
#       Unnamed: 0                 movie_title character  \
# 0              0  10 things i hate about you    bianca
# 1              1  10 things i hate about you   cameron
# 2              2  10 things i hate about you      joey
# 3              3  10 things i hate about you       kat
# 4              4  10 things i hate about you   michael
# ...          ...                         ...       ...
# 3233        3233                  zerophilia    keenan
# 3234        3234                  zerophilia    sydney
# 3235        3235                   zulu dawn  crealock
# 3236        3236                   zulu dawn  pulleine
# 3237        3237                   zulu dawn    storey
#
#                                         memorable_quote
# 0     You're asking me out? That's so cute! What's y...
# 1     Just 'cause you're beautiful, that doesn't mea...
# 2     Watching that bitch violate my car doesn't cou...
# 3     I guess in this society, being male and an ass...
# 4                    I have a dick on my face, don't I?
# ...                                                 ...
# 3233  You're gonna' have a great time with her tonig...
# 3234  That's the thing about the truth. It'll set yo...
# 3235  Excuse me, my Lord, there's something I must c...
# 3236  Well fought, Gentlemen. It's time to save the ...
# 3237  Oh no! Come all this bloody way to get shot by...
#
# [3238 rows x 4 columns]

# %% [markdown]
# We will be using the IMDB API by Octopus Team to get our movie info and the IMDB Scraper API by Oanor to get our actor info. The IMDB APIs have limits for the free plan, so we have to change the key after a certain number of requests.

# %%
num = "1" #the api's have a request limit
#repeat steps appropriate number of times to get all info
df_num = df_memorable.iloc[0: 100, :]
df_num
# Out:
#     Unnamed: 0                 movie_title          character  \
# 0            0  10 things i hate about you             bianca
# 1            1  10 things i hate about you            cameron
# 2            2  10 things i hate about you               joey
# 3            3  10 things i hate about you                kat
# 4            4  10 things i hate about you            michael
# ..         ...                         ...                ...
# 95          95               air force one               rose
# 96          96                    airplane  air controller #1
# 97          97                    airplane        businessman
# 98          98                    airplane         dr. rumack
# 99          99                    airplane          gunderson
#
#                                       memorable_quote
# 0   You're asking me out? That's so cute! What's y...
# 1   Just 'cause you're beautiful, that doesn't mea...
# 2   Watching that bitch violate my car doesn't cou...
# 3   I guess in this society, being male and an ass...
# 4                  I have a dick on my face, don't I?
# ..                                                ...
# 95  . No matter what happens, we land this aircraf...
# 96  I know but this guy has no flying experience a...
# 97  Well, I'll give him another twenty minutes, bu...
# 98  I just want to tell you both good luck. We're ...
# 99  He's all over the place! Nine hundred feet up ...
#
# [100 rows x 4 columns]

# %%
unique_movies = df_num["movie_title"].unique().tolist() #checks movies
unique_movies
# Out:
# ['10 things i hate about you',
#  '1492: conquest of paradise',
#  '15 minutes',
#  '2001: a space odyssey',
#  '8mm',
#  'a bucket of blood',
#  'a clockwork orange',
#  'a few good men',
#  "a hard day's night",
#  'a nightmare on elm street',
#  'a nightmare on elm street 3: dream warriors',
#  'a nightmare on elm street 4: the dream master',
#  "a nightmare on elm street part 2: freddy's revenge",
#  'a nightmare on elm street: the dream child',
#  'a perfect world',
#  'a serious man',
#  'a walk to remember',
#  'above the law',
#  'absolute power',
#  'ace ventura pet detective',
#  'adaptation',
#  'affliction',
#  'after school special',
#  'agnes of god',
#  'air force one',
#  'airplane']

# %%
import requests
from imdb import Cinemagoer # extracts the imdb ID based on a movie name

ia = Cinemagoer()

# %% [markdown]
# This API grabs info about the cast of the specified movie.

# %%
#function for movie id
def get_id(movie_name):
  movies = ia.search_movie(movie_name)
  movie = movies[0]
  return movie.movieID

#function for movie info
def get_movie_info(movie_id):
  url = f"https://imdb236.p.rapidapi.com/imdb/tt{movie_id}/cast"
  headers = {
	"x-rapidapi-key": "e8b568dfbcmshcb2b1b257c05f75p1f4700jsn0675dce0a24d",
	"x-rapidapi-host": "imdb236.p.rapidapi.com"
}
  response = requests.get(url, headers=headers)
  return response.json()

movie_ids = []
movie_jsons = {}
for movie in unique_movies:
  id = get_id(movie)
  movie_ids.append(id)
  movie_json = get_movie_info(id)
  movie_jsons[movie] = movie_json

# %%
movie_json
# Out:
# [{'id': 'nm0001332',
#   'url': 'https://www.imdb.com/name/nm0001332/',
#   'fullName': 'Robert Hays',
#   'job': 'actor',
#   'characters': ['Ted Striker']},
#  {'id': 'nm0353546',
#   'url': 'https://www.imdb.com/name/nm0353546/',
#   'fullName': 'Julie Hagerty',
#   'job': 'actress',
#   'characters': ['Elaine Dickinson']},
#  {'id': 'nm0000558',
#   'url': 'https://www.imdb.com/name/nm0000558/',
#   'fullName': 'Leslie Nielsen',
#   'job': 'actor',
#   'characters': ['Dr. Rumack']},
#  {'id': 'nm0000717',
#   'url': 'https://www.imdb.com/name/nm0000717/',
#   'fullName': 'Kareem Abdul-Jabbar',
#   'job': 'actor',
#   'characters': ['Roger Murdock']},
#  {'id': 'nm0000978',
#   'url': 'https://www.imdb.com/name/nm0000978/',
#   'fullName': 'Lloyd Bridges',
#   'job': 'actor',
#   'characters': ['Steve McCroskey']},
#  {'id': 'nm0336335',
#   'url': 'https://www.imdb.com/name/nm0336335/',
#   'fullName': 'Peter Graves',
#   'job': 'actor',
#   'characters': ['Captain Clarence Oveur']},
#  {'id': 'nm0666309',
#   'url': 'https://www.imdb.com/name/nm0666309/',
#   'fullName': 'Lorna Patterson',
#   'job': 'actress',
#   'characters': ['Randy']},
#  {'id': 'nm0821041',
#   'url': 'https://www.imdb.com/name/nm0821041/',
#   'fullName': 'Robert Stack',
#   'job': 'actor',
#   'characters': ['Captain Rex Kramer']},
#  {'id': 'nm0835992',
#   'url': 'https://www.imdb.com/name/nm0835992/',
#   'fullName': 'Stephen Stucker',
#   'job': 'actor',
#   'characters': ['Johnny Henshaw-Jacobs']},
#  {'id': 'nm1290293',
#   'url': 'https://www.imdb.com/name/nm1290293/',
#   'fullName': 'Otto',
#   'job': 'actor',
#   'characters': ['Otto']},
#  {'id': 'nm0000720',
#   'url': 'https://www.imdb.com/name/nm0000720/',
#   'fullName': 'Jim Abrahams',
#   'job': 'director',
#   'characters': []},
#  {'id': 'nm0001878',
#   'url': 'https://www.imdb.com/name/nm0001878/',
#   'fullName': 'David Zucker',
#   'job': 'director',
#   'characters': []},
#  {'id': 'nm0958387',
#   'url': 'https://www.imdb.com/name/nm0958387/',
#   'fullName': 'Jerry Zucker',
#   'job': 'director',
#   'characters': []},
#  {'id': 'nm0000720',
#   'url': 'https://www.imdb.com/name/nm0000720/',
#   'fullName': 'Jim Abrahams',
#   'job': 'writer',
#   'characters': []},
#  {'id': 'nm0001878',
#   'url': 'https://www.imdb.com/name/nm0001878/',
#   'fullName': 'David Zucker',
#   'job': 'writer',
#   'characters': []},
#  {'id': 'nm0958387',
#   'url': 'https://www.imdb.com/name/nm0958387/',
#   'fullName': 'Jerry Zucker',
#   'job': 'writer',
#   'characters': []},
#  {'id': 'nm0205727',
#   'url': 'https://www.imdb.com/name/nm0205727/',
#   'fullName': 'Jon Davison',
#   'job': 'producer',
#   'characters': []},
#  {'id': 'nm0000930',
#   'url': 'https://www.imdb.com/name/nm0000930/',
#   'fullName': 'Elmer Bernstein',
#   'job': 'composer',
#   'characters': []},
#  {'id': 'nm0005657',
#   'url': 'https://www.imdb.com/name/nm0005657/',
#   'fullName': 'Joseph F. Biroc',
#   'job': 'cinematographer',
#   'characters': []},
#  {'id': 'nm0448269',
#   'url': 'https://www.imdb.com/name/nm0448269/',
#   'fullName': 'Patrick Kennedy',
#   'job': 'editor',
#   'characters': []},
#  {'id': 'nm0862168',
#   'url': 'https://www.imdb.com/name/nm0862168/',
#   'fullName': 'Joel Thurm',
#   'job': 'casting_director',
#   'characters': []},
#  {'id': 'nm0696509',
#   'url': 'https://www.imdb.com/name/nm0696509/',
#   'fullName': 'Ward Preston',
#   'job': 'production_designer',
#   'characters': []}]

# %%
def get_cast(movie_json, character):
  for actor in movie_json:
    roles = [character.lower() for character in actor['characters']]
    for role in roles:
      if character in role:
        return actor['fullName']
  return "actor not found"


def get_actor_id(movie_json, actor_name):
  for actor in movie_json:
    if actor.get("fullName") == actor_name:
      return actor.get("id")
  return None

def get_actor_job(movie_json, actor_id):
  for actor in movie_json:
    if actor.get("id") == actor_id:
      return actor.get("job")
  return None

movie_dict = df_num.groupby("movie_title")["character"].apply(list).to_dict()
movie_dict.keys()
# Out:
# dict_keys(['10 things i hate about you', '1492: conquest of paradise', '15 minutes', '2001: a space odyssey', '8mm', 'a bucket of blood', 'a clockwork orange', 'a few good men', "a hard day's night", 'a nightmare on elm street', 'a nightmare on elm street 3: dream warriors', 'a nightmare on elm street 4: the dream master', "a nightmare on elm street part 2: freddy's revenge", 'a nightmare on elm street: the dream child', 'a perfect world', 'a serious man', 'a walk to remember', 'above the law', 'absolute power', 'ace ventura pet detective', 'adaptation', 'affliction', 'after school special', 'agnes of god', 'air force one', 'airplane'])

# %% [markdown]
# This API will actor info

# %%
def get_actor_info(actor_id):
  url = "https://imdb-scraper3.p.rapidapi.com/api/v1/name/detail"
  querystring = {"id":f"{actor_id}"}
  headers = {
	"x-rapidapi-key": "91514d88a9msh6375841cf39c88bp1054afjsn72bc51c76bb4",
	"x-rapidapi-host": "imdb-scraper3.p.rapidapi.com"
}
  response = requests.get(url, headers=headers, params=querystring)
  return response.json()


def get_age(actor_json):
  return actor_json["data"]["result"].get("birthDate").get("date")


def get_bio(actor_json):
  return actor_json["data"]["result"].get("bio").get("text").get("plainText")

# %% [markdown]
# We extract the info to put into lists which are turned into columns of our dataframe

# %%
actors = []
actor_ids = []
jobs = []
#appends the lists to add to dataframe with corresponding information
for movie in movie_dict.keys():
  for character in movie_dict[movie]:
    actor = get_cast(movie_jsons[movie], character)
    actors.append(actor)
    id = get_actor_id(movie_jsons[movie], actor)
    actor_ids.append(id)
    job = get_actor_job(movie_jsons[movie], id)
    jobs.append(job)

df_num["actor"] = actors
df_num["actor_id"] = actor_ids
df_num["job"] = jobs
df_num = df_num[df_num["actor"] != "actor not found"]
# Out:
# <ipython-input-36-f8429c2497ea>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_num["actor"] = actors
# <ipython-input-36-f8429c2497ea>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_num["actor_id"] = actor_ids
# <ipython-input-36-f8429c2497ea>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_num["job"] = jobs

# %%
#this ensures that we have separate entries for the same actor who acted in
# two different movies / as two different characters in one movie
actor_tuples = [(row.memorable_quote, row.actor_id) for row in
                df_num.itertuples(index=False)]
actor_jsons = {}

len(actor_tuples)
# Out:
# 62

# %% [markdown]
# Run for specific actor info

# %%
for pair in actor_tuples:
  actor_jsons[pair] = get_actor_info(pair[1])

# %%
actor_jsons
# Out:
# {("You're asking me out? That's so cute! What's your name again?",
#   'nm0646351'): {'status': 'ok',
#   'request_id': 'ffcf056a-65fc-4f8f-8004-2846833e5b60',
#   'message': None,
#   'data': {'result': {'id': 'nm0646351',
#     'nameText': {'text': 'Larisa Oleynik', '__typename': 'NameText'},
#     'searchIndexing': {'disableIndexing': False,
#      '__typename': 'NameSearchIndexing'},
#     'disambiguator': {'text': 'I', '__typename': 'Disambiguation'},
#     'knownFor': {'edges': [{'node': {'title': {'titleText': {'text': '10 Dinge, die ich an Dir hasse',
#           '__typename': 'TitleText'},
#          '__typename': 'Title'},
#         'summary': {'principalCategory': {'text': 'Actress',
#           '__typename': 'CreditCategory'},
#          '__typename': 'NameKnownForSummary'},
#         '__typename': 'NameKnownFor'},
#        '__typename': 'NameKnownForEdge'},
#       {'node': {'title': {'titleText': {'text': 'Was ist los mit Alex Mack?',
#           '__typename': 'TitleText'},
#          '__typename': 'Title'},
#         'summary': {'principalCategory': {'text': 'Actress',
#           '__typename': 'CreditCategory'},
#          '__typename': 'NameKnownForSummary'},
#         '__typename': 'NameKnownFor'},
#        '__typename': 'NameKnownForEdge'},
#       {'node': {'title': {'titleText': {'text': "Don't go in the Woods - Es wartet auf dich!",
#           '__typename': 'TitleText'},
#          '__typename': 'Title'},
#         'summary': {'principalCategory': {'text': 'Actress',
#           '__typename': 'CreditCategory'},
#          '__typename': 'NameKnownForSummary'},
#         '__typename': 'NameKnownFor'},
#        '__typename': 'NameKnownForEdge'}],
#      '__typename': 'NameKnownForConnection'},
#     'images': {'total': 90,
#      'edges': [{'node': {'id': 'rm768211456', '__typename': 'Image'},
#        '__typename': 'ImageEdge'}],
#      '__typename': 'ImageConnection'},
#     'primaryImage': {'id': 'rm1240816128',
#      'url': 'https://m.media-amazon.com/images/M/MV5BZDA3MzU3NzUtZDAzOC00NGE3LTg5NjUtNDM4NGI5YmRiNTlkXkEyXkFqcGc@._V1_.jpg',
#      'height': 1000,
#      'width': 1250,
#      'caption': {'plainText': 'Larisa Oleynik', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'meta': {'canonicalId': 'nm0646351',
#      'publicationStatus': 'PUBLISHED',
#      '__typename': 'NameMeta'},
#     'bio': {'text': {'plainText': 'Larisa Oleynik was born in Santa Clara County, California, to Lorraine (Allen), a nurse, and Roman Oleynik, an anesthesiologist. Her father is of Ukrainian and Russian descent.\n\nLarisa\'s big break came when she was eight. She had gotten the part of young Cosette in a production of "Les Misérables". Her costar was Rider Strong, playing Gavroche. The two would be reunited when Larisa guested on Rider\'s sitcom, Das leben und ich (1993). Larisa\'s most well known roles are Bianca in 10 Dinge, die ich an Dir hasse (1999), and Alex in Was ist los mit Alex Mack? (1994).',
#       'plaidHtml': 'Larisa Oleynik was born in Santa Clara County, California, to Lorraine (Allen), a nurse, and Roman Oleynik, an anesthesiologist. Her father is of Ukrainian and Russian descent.<br/><br/>Larisa&#39;s big break came when she was eight. She had gotten the part of young Cosette in a production of &quot;Les Misérables&quot;. Her costar was <a class="ipc-md-link ipc-md-link--entity" href="/name/nm0835045/?ref_=nm_ov_bio_lk">Rider Strong</a>, playing Gavroche. The two would be reunited when Larisa guested on Rider&#39;s sitcom, <a class="ipc-md-link ipc-md-link--entity" href="/title/tt0105958/?ref_=nm_ov_bio_lk">Das leben und ich (1993)</a>. Larisa&#39;s most well known roles are Bianca in <a class="ipc-md-link ipc-md-link--entity" href="/title/tt0147800/?ref_=nm_ov_bio_lk">10 Dinge, die ich an Dir hasse (1999)</a>, and Alex in <a class="ipc-md-link ipc-md-link--entity" href="/title/tt0108921/?ref_=nm_ov_bio_lk">Was ist los mit Alex Mack? (1994)</a>.',
#       '__typename': 'Markdown'},
#      '__typename': 'NameBio'},
#     'primaryProfessions': [{'category': {'text': 'Actress',
#        '__typename': 'CreditCategory'},
#       '__typename': 'PrimaryProfession'},
#      {'category': {'text': 'Soundtrack', '__typename': 'CreditCategory'},
#       '__typename': 'PrimaryProfession'}],
#     'professions': [{'profession': {'text': 'Actress',
#        '__typename': 'DisplayableProfession'},
#       '__typename': 'NameProfession'},
#      {'profession': {'text': 'Soundtrack',
#        '__typename': 'DisplayableProfession'},
#       '__typename': 'NameProfession'}],
#     'birthDate': {'displayableProperty': {'value': {'plainText': 'June 7, 1981',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableDateProperty'},
#      'date': '1981-06-07',
#      'dateComponents': {'day': 7,
#       'month': 6,
#       'year': 1981,
#       'isBCE': False,
#       '__typename': 'DateComponents'},
#      '__typename': 'DisplayableDate'},
#     'deathDate': None,
#     'deathStatus': 'ALIVE',
#     'meterRanking': {'currentRank': 2601,
#      'rankChange': {'changeDirection': 'UP',
#       'difference': 225,
#       '__typename': 'MeterRankChange'},
#      '__typename': 'NameMeterRanking'},
#     'subNavBio': {'id': 'mb0026758', '__typename': 'NameBio'},
#     'subNavTrivia': {'total': 8, '__typename': 'NameTriviaConnection'},
#     'subNavAwardNominations': {'total': 11,
#      '__typename': 'AwardNominationConnection'},
#     'subNavFaqs': {'total': 0, '__typename': 'AlexaQuestionConnection'},
#     'videos': {'total': 18, '__typename': 'VideoConnection'},
#     'primaryVideos': {'edges': [{'node': {'id': 'vi4079273753',
#         'createdDate': '2023-11-13T13:04:28Z',
#         'isMature': False,
#         'runtime': {'value': 57, '__typename': 'VideoRuntime'},
#         'name': {'value': 'Erin & Aaron',
#          'language': 'en',
#          '__typename': 'LocalizedString'},
#         'description': {'value': 'Erin & Aaron',
#          'language': 'en',
#          '__typename': 'LocalizedString'},
#         'timedTextTracks': [],
#         'recommendedTimedTextTrack': None,
#         'thumbnail': {'url': 'https://m.media-amazon.com/images/M/MV5BNGI5ZDQ4YTktZDIwNS00MDVjLWI4M2UtYTYxMzNhYzQzNWQxXkEyXkFqcGdeQVRoaXJkUGFydHlJbmdlc3Rpb25Xb3JrZmxvdw@@._V1_.jpg',
#          'height': 648,
#          'width': 1152,
#          '__typename': 'Thumbnail'},
#         'primaryTitle': {'id': 'tt12225618',
#          'titleText': {'text': 'Erin & Aaron', '__typename': 'TitleText'},
#          'originalTitleText': {'text': 'Erin & Aaron',
#           '__typename': 'TitleText'},
#          'releaseYear': {'year': 2023,
#           '__typename': 'YearRange',
#           'endYear': 2023},
#          '__typename': 'Title',
#          'titleType': {'canHaveEpisodes': True, '__typename': 'TitleType'}},
#         'playbackURLs': [{'displayName': {'value': '480p',
#            'language': 'en-US',
#            '__typename': 'LocalizedString'},
#           'videoMimeType': 'MP4',
#           'videoDefinition': 'DEF_480p',
#           'url': 'https://imdb-video.media-imdb.com/vi4079273753/1434659607842-pgv4ql-1699880668520.mp4?Expires=1742452962&Signature=aUnE-zGhZ7BCFp7pW4-S9gazcj7TxLyFr9PRzDslE1c2RJDn52Pi5fe03zoafImG~ETd5A59zeLrDLmI4LOi~ZlfOOJrGuDDjFjb7XWCMOwIXcuB73bg819AYjk424pVK7jCkIoci3UCs9vAyk8gHzGLFVTnCBuAbpq7mrnjqQlSqMDMm7r792I1rIVQImiUD2dfD4UCDE6VmiEsW6L1fFs8zPHrg2MZuJtNGDYrCwRNzs3LJj63cldx1SRpsVLsY84DP1YQC-7GKlPO3lHIkQ73BUpON00oqFUg1dfZeXZzSwpXZqnu0w0gBIfoPkVCN~22ZnHoESOPvap7Tqx-jA__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA',
#           '__typename': 'PlaybackURL'},
#          {'displayName': {'value': 'SD',
#            'language': 'en-US',
#            '__typename': 'LocalizedString'},
#           'videoMimeType': 'MP4',
#           'videoDefinition': 'DEF_SD',
#           'url': 'https://imdb-video.media-imdb.com/vi4079273753/1434659454657-dx9ykf-1699880668520.mp4?Expires=1742452962&Signature=Vg3JJMjkydH2m~e2kwMW8KT4UU7KDgJzReALnJG3x-E0OIcFJ0GPoqCqakX~KNb25C-tujeBVLF9-bg97I34iZMe61VlPgs7~krrUhIsRBXQHfYRkHf4x3sDMDFTp9vOedDQ2izsp~yTbxawyTOwb4-9M5uQQkw1e5FdYlfvjCjXVO4kLG9q2AE3bxqPfgblcX9P9dHErBYLEwg~L0NEK-YQ558qvOeEDBfegjks8W7tDBqDBTHk9O9xLzRVaDaWWdKCxKaOBO47IIYKcsXXeOrg2kzAKhhNH~eMS3Ka~fXYGFwspegjGYrWvhMc-PiD8~4LvO~CQso2MY~pU2pJeA__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA',
#           '__typename': 'PlaybackURL'}],
#         'contentType': {'id': 'amzn1.imdb.video.contenttype.trailer',
#          'displayName': {'value': 'Trailer', '__typename': 'LocalizedString'},
#          '__typename': 'VideoContentType'},
#         'previewURLs': [{'displayName': {'value': 'AUTO',
#            'language': 'en-US',
#            '__typename': 'LocalizedString'},
#           'videoMimeType': 'M3U8',
#           'videoDefinition': 'DEF_AUTO',
#           'url': 'https://imdb-video.media-imdb.com/vi4079273753/hls-preview-b7eb3f8d-1996-4751-a09d-8898e9551b2e.m3u8?Expires=1742452962&Signature=H7-rbdc6-7U3s1FD~Yrmbd0RcgSHqrvG11A4ouSEEE9Gs5r97pf1VunIuod0bpI07eMHEp-n-ST2dKtE5J2pYwSwP1xJuiF~LO15mDqRfB9ALHBTIJHq5B9GjC5g4ljSZFVELZ-ZFaOJKCNm2AWV343YRTdfc8yaLJz-rfszfXtjGpLWM7BpHvhF0~QWR-0IbLi4NJ2zl2G5qqMl5fNDRrvyPaXb8mMtgJTD1yUGIVZuf3Y78b3czGx6UZXf0qeVM88lChZK7kHBO2J~SVXQD4cnklNRddmNNDnQVDcy17fe5gNfYkH7LVfsxGVDistQNv5T41u9PMfC5Y2sr0v5iw__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA',
#           '__typename': 'PlaybackURL'}],
#         '__typename': 'Video'},
#        '__typename': 'VideoEdge'}],
#      '__typename': 'VideoConnection'},
#     '__typename': 'Name'}}},
#  ("Just 'cause you're beautiful, that doesn't mean that you can treat people like they don't matter._And I'm BACK IN THE GAME!_You embarrassed the girl. Sacrifice yourself on the alter of dignity and even the score.",
#   'nm0330687'): {'status': 'ok',
#   'request_id': 'c988851a-65f8-4c56-a0c1-eb6ce75e0eb6',
#   'message': None,
#   'data': {'result': {'id': 'nm0330687',
#     'nameText': {'text': 'Joseph Gordon-Levitt', '__typename': 'NameText'},
#     'searchIndexing': {'disableIndexing': False,
#      '__typename': 'NameSearchIndexing'},
#     'disambiguator': None,
#     'knownFor': {'edges': [{'node': {'title': {'titleText': {'text': 'Inception',
#           '__typename': 'TitleText'},
#          '__typename': 'Title'},
#         'summary': {'principalCategory': {'text': 'Actor',
#           '__typename': 'CreditCategory'},
#          '__typename': 'NameKnownForSummary'},
#         '__typename': 'NameKnownFor'},
#        '__typename': 'NameKnownForEdge'},
#       {'node': {'title': {'titleText': {'text': 'Looper',
#           '__typename': 'TitleText'},
#          '__typename': 'Title'},
#         'summary': {'principalCategory': {'text': 'Actor',
#           '__typename': 'CreditCategory'},
#          '__typename': 'NameKnownForSummary'},
#         '__typename': 'NameKnownFor'},
#        '__typename': 'NameKnownForEdge'},
#       {'node': {'title': {'titleText': {'text': 'Don Jon',
#           '__typename': 'TitleText'},
#          '__typename': 'Title'},
#         'summary': {'principalCategory': {'text': 'Actor',
#           '__typename': 'CreditCategory'},
#          '__typename': 'NameKnownForSummary'},
#         '__typename': 'NameKnownFor'},
#        '__typename': 'NameKnownForEdge'}],
#      '__typename': 'NameKnownForConnection'},
#     'images': {'total': 1906,
#      'edges': [{'node': {'id': 'rm3583403520', '__typename': 'Image'},
#        '__typename': 'ImageEdge'}],
#      '__typename': 'ImageConnection'},
#     'primaryImage': {'id': 'rm2827403520',
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTY3NTk0NDI3Ml5BMl5BanBnXkFtZTgwNDA3NjY0MjE@._V1_.jpg',
#      'height': 2048,
#      'width': 1421,
#      'caption': {'plainText': 'Joseph Gordon-Levitt',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'meta': {'canonicalId': 'nm0330687',
#      'publicationStatus': 'PUBLISHED',
#      '__typename': 'NameMeta'},
#     'bio': {'text': {'plainText': "Joseph Gordon-Levitt is an actor, filmmaker, and entrepreneur known for films such as 500 Days of Summer, Inception, Looper, and Snowden. He recently co-starred in the #1 Netflix hit, Beverly Hills Cop: Axel F and as the infamous founder of Uber in Showtime's Super-Pumped. He wrote and directed the prescient Sundance favorite, Don Jon about online pornography addiction, and followed with the Apple TV+ series, Mr. Corman. Gordon-Levitt has always been passionate about the intersection of media and technology, co-founding the two-time Emmy-winning online community for creative collaboration, hitRECord. He recently penned a Washington Post OpEd entitled 'If artificial intelligence uses your work, it should pay you', and spoke at Taiwan's Plurality Summit in support of its luminary Minister of Digital Affairs, Audrey Tang.",
#       'plaidHtml': 'Joseph Gordon-Levitt is an actor, filmmaker, and entrepreneur known for films such as 500 Days of Summer, Inception, Looper, and Snowden. He recently co-starred in the #1 Netflix hit, Beverly Hills Cop: Axel F and as the infamous founder of Uber in Showtime&#39;s Super-Pumped. He wrote and directed the prescient Sundance favorite, Don Jon about online pornography addiction, and followed with the Apple TV+ series, Mr. Corman. Gordon-Levitt has always been passionate about the intersection of media and technology, co-founding the two-time Emmy-winning online community for creative collaboration, hitRECord. He recently penned a Washington Post OpEd entitled &#39;If artificial intelligence uses your work, it should pay you&#39;, and spoke at Taiwan&#39;s Plurality Summit in support of its luminary Minister of Digital Affairs, Audrey Tang.',
#       '__typename': 'Markdown'},
#      '__typename': 'NameBio'},
#     'primaryProfessions': [{'category': {'text': 'Actor',
#        '__typename': 'CreditCategory'},
#       '__typename': 'PrimaryProfession'},
#      {'category': {'text': 'Producer', '__typename': 'CreditCategory'},
#       '__typename': 'PrimaryProfession'},
#      {'category': {'text': 'Writer', '__typename': 'CreditCategory'},
#       '__typename': 'PrimaryProfession'}],
#     'professions': [{'profession': {'text': 'Actor',
#        '__typename': 'DisplayableProfession'},
#       '__typename': 'NameProfession'},
#      {'profession': {'text': 'Producer',
#        '__typename': 'DisplayableProfession'},
#       '__typename': 'NameProfession'},
#      {'profession': {'text': 'Writer', '__typename': 'DisplayableProfession'},
#       '__typename': 'NameProfession'}],
#     'birthDate': {'displayableProperty': {'value': {'plainText': 'February 17, 1981',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableDateProperty'},
#      'date': '1981-02-17',
#      'dateComponents': {'day': 17,
#       'month': 2,
#       'year': 1981,
#       'isBCE': False,
#       '__typename': 'DateComponents'},
#      '__typename': 'DisplayableDate'},
#     'deathDate': None,
#     'deathStatus': 'ALIVE',
#     'meterRanking': {'currentRank': 644,
#      'rankChange': {'changeDirection': 'DOWN',
#       'difference': 135,
#       '__typename': 'MeterRankChange'},
#      '__typename': 'NameMeterRanking'},
#     'subNavBio': {'id': 'mb0608880', '__typename': 'NameBio'},
#     'subNavTrivia': {'total': 34, '__typename': 'NameTriviaConnection'},
#     'subNavAwardNominations': {'total': 102,
#      '__typename': 'AwardNominationConnection'},
#     'subNavFaqs': {'total': 0, '__typename': 'AlexaQuestionConnection'},
#     'videos': {'total': 148, '__typename': 'VideoConnection'},
#     'primaryVideos': {'edges': [{'node': {'id': 'vi354600217',
#         'createdDate': '2023-01-31T17:29:39Z',
#         'isMature': False,
#         'runtime': {'value': 112, '__typename': 'VideoRuntime'},
#         'name': {'value': 'Why Nobody Thought Joseph Gordon-Levitt Could Be in Sundance Movies',
#          'language': 'en',
#          '__typename': 'LocalizedString'},
#         'description': {'value': 'Back when he was in "3rd Rock from the Sun" and \'10 Things I Hate About You,\' Joseph Gordon-Levitt yearned to test his dramatic chops with a Sundance film. When the opportunity came in the form of 2001\'s \'Manic\' with Zooey Deschanel and Don Cheadle, the young star embraced the challenge. Although the early digital film didn\'t get much attention at the Sundance Film Festival (unlike his 2023 festival favorite, John Carney\'s \'Flora and Son\'), Lyle in \'Manic\' is the role that forever changed Gordon-Levitt\'s life.',
#          'language': 'en',
#          '__typename': 'LocalizedString'},
#         'timedTextTracks': [],
#         'recommendedTimedTextTrack': None,
#         'thumbnail': {'url': 'https://m.media-amazon.com/images/M/MV5BY2U5N2RkNjktYWJkYi00NTVjLTgzNzAtMGRlN2U1NmQ3ZWM2XkEyXkFqcGdeQWFsZWxvZw@@._V1_.jpg',
#          'height': 1080,
#          'width': 1920,
#          '__typename': 'Thumbnail'},
#         'primaryTitle': {'id': 'tt26545169',
#          'titleText': {'text': 'Joseph Gordon-Levitt on the Role That Changed His Life',
#           '__typename': 'TitleText'},
#          'originalTitleText': {'text': 'Joseph Gordon-Levitt on the Role That Changed His Life',
#           '__typename': 'TitleText'},
#          'releaseYear': None,
#          '__typename': 'Title',
#          'titleType': {'canHaveEpisodes': False, '__typename': 'TitleType'}},
#         'playbackURLs': [{'displayName': {'value': '480p',
#            'language': 'en-US',
#            '__typename': 'LocalizedString'},
#           'videoMimeType': 'MP4',
#           'videoDefinition': 'DEF_480p',
#           'url': 'https://imdb-video.media-imdb.com/vi354600217/1434659607842-pgv4ql-1675186179483.mp4?Expires=1742452158&Signature=p6v1PQqzFdM3glODfhSgFeDNw6IIqY2CGEFzR7nQTe0uVW3epua0bEF-I3i06aoAPFng9cw7WNjjW5pwNVqyqMHQTMmqTQVyVhPUAfasD5enLRfV9sM~gK5RBsVaiDyq1MrSsmbxLjZXkJLLlA~cdAVIGFHsiMg1b26BBq1LYjbI8KL6NgCQb9~F6JOzsFgfdQ3VKkjR3WrwYaxFnNq7toRdHM1qVFoY6nB4easIfsLWRCZKpJdBDfwrRZwDS~3zEbzc~1OPOtM24Zeu72hHGVFIIrpHhffr2~OcN~jfaMDhMhWMaG9NzMQ3vlTjG5g2NPeYHlodjTWLxocngmbiGw__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA',
#           '__typename': 'PlaybackURL'},
#          {'displayName': {'value': 'SD',
#            'language': 'en-US',
#            '__typename': 'LocalizedString'},
#           'videoMimeType': 'MP4',
#           'videoDefinition': 'DEF_SD',
#           'url': 'https://imdb-video.media-imdb.com/vi354600217/1434659454657-dx9ykf-1675186179483.mp4?Expires=1742452158&Signature=aibeskuMg5xChAI1KKmXPvAPgdd6Ton6gYM8UQNUA2CTsKTcq4OYrbNVq-RJWII06epBe9K7qm03Xv5aEfL5g8tphi9XZbQUqaBW~QsYb6cQGL9me35~XAfVLWEwiILT0gi2VTjeIJ06mD-Y1aaX1mUJZN73zAKlAv3f2UnnTGcNaeKHGgm1OmvhC0NxcJ-GxYjPRfaGDoV~FRY4VPzL2f2NUUUDwrA8~8HGgFVaYH7CXfpfO-UP6cVgP5ikdKBDoc7eHE3EHrP0vMc~t5zmwCAKhexpIWwGxX7rBcqwW~ATuYxlUY4W6d6siAZNesGT7yHnhcqe59LHiYKPBNJreg__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA',
#           '__typename': 'PlaybackURL'}],
#         'contentType': {'id': 'amzn1.imdb.video.contenttype.clip',
#          'displayName': {'value': 'Clip', '__typename': 'LocalizedString'},
#          '__typename': 'VideoContentType'},
#         'previewURLs': [{'displayName': {'value': 'AUTO',
#            'language': 'en-US',
#            '__typename': 'LocalizedString'},
#           'videoMimeType': 'M3U8',
#           'videoDefinition': 'DEF_AUTO',
#           'url': 'https://imdb-video.media-imdb.com/vi354600217/hls-preview-4f5ea6b5-9811-4e2c-9d8f-4423b9c97695.m3u8?Expires=1742452158&Signature=ZiYaToCLqORKY7oYVGZu49i53~FiOaXOqZH3xF8ZWVgXPxWPSYTHee2ezSJlQBLaMWbHQsid0IO8ADlFjI0nxBZZBsqw2SHRjiHEvAZI57Glr5lt8hcnHhsW1UP6EVzHDJxJF5MBfqDZcYRj1uiofOPf9MosuHjVuAJr1DudMUVG~mKV0BSr-nu1fd-j8fwLjGyT~rd741DQJbIY2Eyjudl0xfBNLiRVfqZrd56mkeZhRj3vb9jJjHqPjwk99jWTAaeFh-SINe8yqe-6LodB6iAVbJbLMoY9ihsItrsDQ2ZkZH4alIAzJxL0Rge0bg2Ft87Fk~aRieAnATSTy-AIoQ__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA',
#           '__typename': 'PlaybackURL'}],
#         '__typename': 'Video'},
#        '__typename': 'VideoEdge'}],
#      '__typename': 'VideoConnection'},
#     '__typename': 'Name'}}},
#  ("Watching that bitch violate my car doesn't count as a date.",
#   'nm0005080'): {'status': 'ok',
#   'request_id': '2451e416-2e58-4b0d-889d-09d27f07ae1e',
#   'message': None,
#   'data': {'result': {'id': 'nm0005080',
#     'nameText': {'text': 'Andrew Keegan', '__typename': 'NameText'},
#     'searchIndexing': {'disableIndexing': False,
#      '__typename': 'NameSearchIndexing'},
#     'disambiguator': {'text': 'I', '__typename': 'Disambiguation'},
#     'knownFor': {'edges': [{'node': {'title': {'titleText': {'text': '10 Dinge, die ich an Dir hasse',
#           '__typename': 'TitleText'},
#          '__typename': 'Title'},
#         'summary': {'principalCategory': {'text': 'Actor',
#           '__typename': 'CreditCategory'},
#          '__typename': 'NameKnownForSummary'},
#         '__typename': 'NameKnownFor'},
#        '__typename': 'NameKnownForEdge'},
#       {'node': {'title': {'titleText': {'text': 'Independence Day',
#           '__typename': 'TitleText'},
#          '__typename': 'Title'},
#         'summary': {'principalCategory': {'text': 'Actor',
#           '__typename': 'CreditCategory'},
#          '__typename': 'NameKnownForSummary'},
#         '__typename': 'NameKnownFor'},
#        '__typename': 'NameKnownForEdge'},
#       {'node': {'title': {'titleText': {'text': 'Der Club der gebrochenen Herzen - Eine romantische Komödie',
#           '__typename': 'TitleText'},
#          '__typename': 'Title'},
#         'summary': {'principalCategory': {'text': 'Actor',
#           '__typename': 'CreditCategory'},
#          '__typename': 'NameKnownForSummary'},
#         '__typename': 'NameKnownFor'},
#        '__typename': 'NameKnownForEdge'}],
#      '__typename': 'NameKnownForConnection'},
#     'images': {'total': 85,
#      'edges': [{'node': {'id': 'rm3386673920', '__typename': 'Image'},
#        '__typename': 'ImageEdge'}],
#      '__typename': 'ImageConnection'},
#     'primaryImage': {'id': 'rm1897566977',
#      'url': 'https://m.media-amazon.com/images/M/MV5BMzU4MjI3MWQtNTliOS00YjJmLTg0M2QtNDEyNmZkN2U1YTBiXkEyXkFqcGc@._V1_.jpg',
#      'height': 640,
#      'width': 427,
#      'caption': {'plainText': 'Andrew Keegan', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'meta': {'canonicalId': 'nm0005080',
#      'publicationStatus': 'PUBLISHED',
#      '__typename': 'NameMeta'},
#     'bio': {'text': {'plainText': 'Andrew Keegan was born in Shadow Hills, California. He was first recognized for his gregarious performance of teen rebel "Zack Dell in the cult-classic film Ferien total verrückt (1994). Barely in high school, Roland Emmerich cast Keegan in the blockbuster Independence Day (1996). After an immediate rise in popularity, the charismatic actor guest-starred on many hit shows before being cast on the TV drama Party of Five (1994). That same year, he landed another recurring role on Eine himmlische Familie (1996), the WB\'s longest-running hit series, on which he played a single teenaged father in love with Jessica Biel\'s character Mary. Keegan showed his range from comedy to drama in two modern-day Shakespearean film adaptations. His hilarious performance as the antagonist of Heath Ledger in the comedy 10 Dinge, die ich an Dir hasse (1999) was balanced by a solid dramatic performance as Mekhi Phifer\'s best friend in O (1995), which was directed by Tim Blake Nelson.\n\nA bold choice in his career, Keegan accepted the lead role in Greg Berlanti\'s critically acclaimed Der Club der gebrochenen Herzen - Eine romantische Komödie (2000), which showed a more vulnerable side of his acting range as the newbie. The film won best picture that year at the GLAAD Awards. Expanding his range in 2009, Keegan made his theatrical stage debut in the provocative award winning play "He Asked For It." Keegan stepped on stage as Rigby, a character tackling the emotional issues of being HIV-positive in modern-day society. In 2010, Keegan jumped into the cockpit as Strayger, a drug-smuggling pilot in the high-octane action film Kill Speed - Lebe schnell ... stirb jung! (2010). Innovative camera technology allowed the adrenaline-driven actor to give his performance while doing aeronautical stunts in mid-flight.\n\nAlongside William Sadler and John Heard, Keegan took on a darker role as a sadistic and sociopathic vampire named Blake in the film Living Among Us (2018).',
#       'plaidHtml': 'Andrew Keegan was born in Shadow Hills, California. He was first recognized for his gregarious performance\nof teen rebel &quot;Zack Dell in the cult-classic film <a class="ipc-md-link ipc-md-link--entity" href="/title/tt0109369/?ref_=nm_ov_bio_lk">Ferien total verrückt (1994)</a>.\nBarely in high school, <a class="ipc-md-link ipc-md-link--entity" href="/name/nm0000386/?ref_=nm_ov_bio_lk">Roland Emmerich</a> cast Keegan in the blockbuster\n<a class="ipc-md-link ipc-md-link--entity" href="/title/tt0116629/?ref_=nm_ov_bio_lk">Independence Day (1996)</a>. After an immediate rise in popularity, the\ncharismatic actor guest-starred on many hit shows before being cast on\nthe TV drama <a class="ipc-md-link ipc-md-link--entity" href="/title/tt0108894/?ref_=nm_ov_bio_lk">Party of Five (1994)</a>. That same year, he landed another\nrecurring role on <a class="ipc-md-link ipc-md-link--entity" href="/title/tt0115083/?ref_=nm_ov_bio_lk">Eine himmlische Familie (1996)</a>, the WB&#39;s longest-running hit series,\non which he played a single teenaged father in love with <a class="ipc-md-link ipc-md-link--entity" href="/name/nm0004754/?ref_=nm_ov_bio_lk">Jessica Biel</a>&#39;s character\nMary. Keegan showed his range from comedy to drama in two modern-day\nShakespearean film adaptations. His hilarious performance as the\nantagonist of <a class="ipc-md-link ipc-md-link--entity" href="/name/nm0005132/?ref_=nm_ov_bio_lk">Heath Ledger</a> in the comedy <a class="ipc-md-link ipc-md-link--entity" href="/title/tt0147800/?ref_=nm_ov_bio_lk">10 Dinge, die ich an Dir hasse (1999)</a>\nwas balanced by a solid dramatic performance as <a class="ipc-md-link ipc-md-link--entity" href="/name/nm0001616/?ref_=nm_ov_bio_lk">Mekhi Phifer</a>&#39;s best\nfriend in <a class="ipc-md-link ipc-md-link--entity" href="/title/tt2171840/?ref_=nm_ov_bio_lk">O (1995)</a>, which was directed by <a class="ipc-md-link ipc-md-link--entity" href="/name/nm0625789/?ref_=nm_ov_bio_lk">Tim Blake Nelson</a>.<br/><br/>A bold choice in his career, Keegan accepted the lead role in <a class="ipc-md-link ipc-md-link--entity" href="/name/nm0075528/?ref_=nm_ov_bio_lk">Greg Berlanti</a>&#39;s critically acclaimed <a class="ipc-md-link ipc-md-link--entity" href="/title/tt0222850/?ref_=nm_ov_bio_lk">Der Club der gebrochenen Herzen - Eine romantische Komödie (2000)</a>, which showed a more\nvulnerable side of his acting range as the newbie. The film won best picture that year\nat the GLAAD Awards. Expanding his range in 2009, Keegan made his\ntheatrical stage debut in the provocative award winning play &quot;He Asked\nFor It.&quot; Keegan stepped on stage as Rigby, a character tackling the\nemotional issues of being HIV-positive in modern-day society. In 2010,\nKeegan jumped into the cockpit as Strayger, a drug-smuggling pilot in\nthe high-octane action film <a class="ipc-md-link ipc-md-link--entity" href="/title/tt1027683/?ref_=nm_ov_bio_lk">Kill Speed - Lebe schnell ... stirb jung! (2010)</a>. Innovative camera technology\nallowed the adrenaline-driven actor to give his performance while doing\naeronautical stunts in mid-flight.<br/><br/>Alongside <a class="ipc-md-link ipc-md-link--entity" href="/name/nm0006669/?ref_=nm_ov_bio_lk">William Sadler</a> and <a class="ipc-md-link ipc-md-link--entity" href="/name/nm0001334/?ref_=nm_ov_bio_lk">John Heard</a>, Keegan took on a\ndarker role as a sadistic and sociopathic vampire named Blake in the film\n<a class="ipc-md-link ipc-md-link--entity" href="/title/tt3334418/?ref_=nm_ov_bio_lk">Living Among Us (2018)</a>.',
#       '__typename': 'Markdown'},
#      '__typename': 'NameBio'},
#     'primaryProfessions': [{'category': {'text': 'Actor',
#        '__typename': 'CreditCategory'},
#       '__typename': 'PrimaryProfession'},
#      {'category': {'text': 'Producer', '__typename': 'CreditCategory'},
#       '__typename': 'PrimaryProfession'}],
#     'professions': [{'profession': {'text': 'Actor',
#        '__typename': 'DisplayableProfession'},
#       '__typename': 'NameProfession'},
#      {'profession': {'text': 'Producer',
#        '__typename': 'DisplayableProfession'},
#       '__typename': 'NameProfession'}],
#     'birthDate': {'displayableProperty': {'value': {'plainText': 'January 29, 1979',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableDateProperty'},
#      'date': '1979-01-29',
#      'dateComponents': {'day': 29,
#       'month': 1,
#       'year': 1979,
#       'isBCE': False,
#       '__typename': 'DateComponents'},
#      '__typename': 'DisplayableDate'},
#     'deathDate': None,
#     'deathStatus': 'ALIVE',
#     'meterRanking': None,
#     'subNavBio': {'id': 'mb0018790', '__typename': 'NameBio'},
#     'subNavTrivia': {'total': 10, '__typename': 'NameTriviaConnection'},
#     'subNavAwardNominations': {'total': 6,
#      '__typename': 'AwardNominationConnection'},
#     'subNavFaqs': {'total': 10, '__typename': 'AlexaQuestionConnection'},
#     'videos': {'total': 18, '__typename': 'VideoConnection'},
#     'primaryVideos': {'edges': [{'node': {'id': 'vi3948332569',
#         'createdDate': '2024-09-19T04:14:17Z',
#         'isMature': False,
#         'runtime': {'value': 151, '__typename': 'VideoRuntime'},
#         'name': {'value': 'The Activated Man Trailer',
#          'language': 'en',
#          '__typename': 'LocalizedString'},
#         'description': {'value': 'After Ors Gabriel loses his beloved dog to cancer, the trauma leads to strange visions of a shadowy figure known as The Fedora Man. While Ors is pushed to the limits of his sanity, a mysterious surge of murder-suicides in the city reveals dark secrets from his past, forcing Ors to finally embrace who he really is, and what he is meant to become.',
#          'language': 'en',
#          '__typename': 'LocalizedString'},
#         'timedTextTracks': [],
#         'recommendedTimedTextTrack': None,
#         'thumbnail': {'url': 'https://m.media-amazon.com/images/M/MV5BNDEzNTE0NjQtMTkxNy00NDk5LWJmM2QtODkwZDFmYjM4MzY5XkEyXkFqcGdeQXRyYW5zY29kZS13b3JrZmxvdw@@._V1_.jpg',
#          'height': 798,
#          'width': 1920,
#          '__typename': 'Thumbnail'},
#         'primaryTitle': {'id': 'tt26753672',
#          'titleText': {'text': 'The Activated Man', '__typename': 'TitleText'},
#          'originalTitleText': {'text': 'The Activated Man',
#           '__typename': 'TitleText'},
#          'releaseYear': {'year': 2023,
#           '__typename': 'YearRange',
#           'endYear': None},
#          '__typename': 'Title',
#          'titleType': {'canHaveEpisodes': False, '__typename': 'TitleType'}},
#         'playbackURLs': [{'displayName': {'value': '480p',
#            'language': 'en-US',
#            '__typename': 'LocalizedString'},
#           'videoMimeType': 'MP4',
#           'videoDefinition': 'DEF_480p',
#           'url': 'https://imdb-video.media-imdb.com/vi3948332569/1434659607842-pgv4ql-1726719257780.mp4?Expires=1742452967&Signature=ob5QwQdObIxMAVhZ9Qim4l0PWaa1~zaM25pxrB16vpUHz2IJsns3-KT~cF5tJ7usM8FEHZVOgeU4nPm3d4PR4PoBpqs-JSnlUloY~rTjfzKJGXffCLA0JplZ~-Q951WuID1kMmY21eAf2fa8ZfgPSTI0r7weYlqtMZNcTPVq~ebN3tvLOwChOjRz0Qb8axrJq6snt2elyk0UXi6kVF4CKTHW45HQP7KX8XLotbx8zf~C0yZntX~ugWH2VIQmNBH0bv5S9ELKKUDvOPsnhctNoEUBAwNFvZ1F5SGipmLyOO9CS5VXvcTe6ZGSCaux2e7gO1H1bROe4frlPqqEM2PBSw__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA',
#           '__typename': 'PlaybackURL'},
#          {'displayName': {'value': 'SD',
#            'language': 'en-US',
#            '__typename': 'LocalizedString'},
#           'videoMimeType': 'MP4',
#           'videoDefinition': 'DEF_SD',
#           'url': 'https://imdb-video.media-imdb.com/vi3948332569/1434659454657-dx9ykf-1726719257780.mp4?Expires=1742452967&Signature=byWvW2XbDgQitOM1RWbP1hDQ0JQXMnbDMkjPUpXaimUf3eBkYmKkXL3Ozb-MIFG0EowVQZTDqU0ymKQGkHfwxHlWjxAgjvvMQDvvxMc82SZVJopnJ9D~KKI9BzKn-PRCoufOPfEFDjBiLc~gNfkzkMWdRPLO4AShWt-6P~gh9AzIhiur3x4SPj58VEDG5Ndytr2pj0AaCrWht9KLKAfVxaK-J63se-eaEJlCJHntMd3UKolya4UjW~0gnwrVmJujOTS8fxnnY4cDDxMJLmUPJWC4F8keHSSE~89ymHOvYdJOPqe4hqW3wFg7qki3Xt7pr46WO-PZwVextI1-yIbrvQ__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA',
#           '__typename': 'PlaybackURL'}],
#         'contentType': {'id': 'amzn1.imdb.video.contenttype.trailer',
#          'displayName': {'value': 'Trailer', '__typename': 'LocalizedString'},
#          '__typename': 'VideoContentType'},
#         'previewURLs': [{'displayName': {'value': 'AUTO',
#            'language': 'en-US',
#            '__typename': 'LocalizedString'},
#           'videoMimeType': 'M3U8',
#           'videoDefinition': 'DEF_AUTO',
#           'url': 'https://imdb-video.media-imdb.com/vi3948332569/hls-preview-049f7bf2-47b7-449c-834b-dd91dce3c8f4.m3u8?Expires=1742452967&Signature=llScIFdXRXOH3sN-tp1uybJ9eqAhZkCHrJWfvl8e63conrkXdaGyJWE~uSZX~~iIB0yPBgnB5BuPj9MR~BoTQIt71~VjuUSlsadaHdTmED~TCCAJuKqiPPcqy9AduXCk-u04BtwZFCe1a-CBUofejFdCc6cA7NoVYNUwKrTVCw1K6RL3JPuiINpvs89IM7f68ntpnxRIgE3TdMJ-pWTjhtVL6ZTkD2ibTXt7JH-qNYiGVwJrD-9d8tG5~tD12~--sHYNK~yFCna~RM9z1LOQhZv4GEkfEWOfFyDUS5OiKyCCq2Y9gSZpR7fTuS55FW-fzg~OOa73LH6vjCCwPRls6w__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA',
#           '__typename': 'PlaybackURL'}],
#         '__typename': 'Video'},
#        '__typename': 'VideoEdge'}],
#      '__typename': 'VideoConnection'},
#     '__typename': 'Name'}}},
#  ("I guess in this society, being male and an asshole makes you worthy of our time._You're not as vile as I thought you were._Oh wait... was that... did your hairline just recede?_Remove head from sphincter, then drive!",
#   'nm0005466'): {'status': 'ok',
#   'request_id': '86179fe5-24fb-4443-a6a1-68af886c5bf4',
#   'message': None,
#   'data': {'result': {'id': 'nm0005466',
#     'nameText': {'text': 'Julia Stiles', '__typename': 'NameText'},
#     'searchIndexing': {'disableIndexing': False,
#      '__typename': 'NameSearchIndexing'},
#     'disambiguator': {'text': 'I', '__typename': 'Disambiguation'},
#     'knownFor': {'edges': [{'node': {'title': {'titleText': {'text': '10 Dinge, die ich an Dir hasse',
#           '__typename': 'TitleText'},
#          '__typename': 'Title'},
#         'summary': {'principalCategory': {'text': 'Actress',
#           '__typename': 'CreditCategory'},
#          '__typename': 'NameKnownForSummary'},
#         '__typename': 'NameKnownFor'},
#        '__typename': 'NameKnownForEdge'},
#       {'node': {'title': {'titleText': {'text': 'Save the Last Dance',
#           '__typename': 'TitleText'},
#          '__typename': 'Title'},
#         'summary': {'principalCategory': {'text': 'Actress',
#           '__typename': 'CreditCategory'},
#          '__typename': 'NameKnownForSummary'},
#         '__typename': 'NameKnownFor'},
#        '__typename': 'NameKnownForEdge'},
#       {'node': {'title': {'titleText': {'text': 'Silver Linings',
#           '__typename': 'TitleText'},
#          '__typename': 'Title'},
#         'summary': {'principalCategory': {'text': 'Actress',
#           '__typename': 'CreditCategory'},
#          '__typename': 'NameKnownForSummary'},
#         '__typename': 'NameKnownFor'},
#        '__typename': 'NameKnownForEdge'}],
#      '__typename': 'NameKnownForConnection'},
#     'images': {'total': 454,
#      'edges': [{'node': {'id': 'rm1854443522', '__typename': 'Image'},
#        '__typename': 'ImageEdge'}],
#      '__typename': 'ImageConnection'},
#     'primaryImage': {'id': 'rm1896056064',
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTgxNjUxNDk3MF5BMl5BanBnXkFtZTcwMzM0NjA0NA@@._V1_.jpg',
#      'height': 2048,
#      'width': 1367,
#      'caption': {'plainText': 'Julia Stiles', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'meta': {'canonicalId': 'nm0005466',
#      'publicationStatus': 'PUBLISHED',
#      '__typename': 'NameMeta'},
#     'bio': {'text': {'plainText': 'Lovely, Julia (O\'Hara) Stiles, of Irish, English and German heritage, was born on March 28, 1981 in New York City, the outgoing daughter and eldest of three children of a Greenwich Village artist mother, Judith Newcomb Stiles, and an elementary school teacher father, John O\'Hara.\n\nEncouraged to take modern dance lessons, she was introduced to Shakespeare and theater at an early age. When she was 11, she made her stage debut as a child actress with the experimental off-Broadway La MaMa Theatre. Her passion grew and by the next year was performing professionally and working in commercials. A bright, precocious student, she was seriously considered for the child vampire role of Claudia in Interview mit einem Vampir (1994) but lost out in the end to Kirsten Dunst. She continued training at New York\'s Professional Children\'s School and, at 15, made her cinematic bow with I Love You, I Love You Not (1996) with Claire Danes.\n\nJulia was next featured as the daughter of Harrison Ford in Vertrauter Feind (1997), with her breakout role occurring on TV with the hard-hitting mini-movie Wie ein Vogel ohne Flügel (1997), which was produced by Oprah Winfrey and dealt with child abuse. Her wish to play Shakespeare was granted threefold with her participation in 10 Dinge, die ich an Dir hasse (1999), which was based on the Bard\'s "The Taming of The Shrew" and earned her the Chicago Film Critics Award as volatile teen Kat; an updated version of Hamlet (2000) which paired her Ophelia with Ethan Hawke; and another updated version of "Othello" entitled O - Vertrauen, Verführung, Verrat (2001), which involved her high school character of Desi (Desdemona) in a mixed romantic relationship with African-American Mekhi Phifer. The violent-edged film, made in 1998, was not released until three years later due to the Colorado shootings at Columbine High School.\n\nIn addition, Julia later portrayed Viola off-Broadway in a Shakespeare-in-the-Park production of "Twelfth Night" in 2002. She temporarily interrupted her career after deciding to enroll at Columbia University in 2000, where she earned a degree in English. Stiles has also returned to the stage, appearing in David Mamet\'s "Oleanna" in London, a role she would reprise on Broadway in 2009, opposite Bill Pullman and directed by Doug Hughes.\n\nMoving into mainstream roles by the millennium, Julia took on a role that would carry her through the decade, co-starring with Matt Damon in popular Bourne series: Die Bourne Identität (2002), Die Bourne Verschwörung (2004) and Das Bourne Ultimatum (2007). During the time between Bourne films, she appeared in ensemble dramas, appearing opposite Julia Roberts in Mona Lisas Lächeln (2003), won offbeat notice in the title role of Carolina - Auf der Suche nach Mr. Perfect (2003) with Shirley MacLaine and Randy Quaid. She also returned to her indie film roots, with films such as Between Us (2012) and the comedy farce, It\'s a Disaster - Bist du bereit? (2012).\n\nIn 2010, Julia switched gears and headed to series television, joining the cast of Dexter (2006) for the show\'s fifth season as Lumen Pierce, a performance that earned her Emmy and Golden Globe support nominations. In 2012, she followed this up with leads in two other TV series, the social drama Blue (2012) and the dramatic thriller Riviera (2017).\n\nMarried to camera assistant Preston Cook and with one son, Julia\'s more recent filming has included prominent roles in Gilly Hopkins - Eine wie keine (2015), Ruf der Macht - Im Sumpf der Korruption (2016), Jason Bourne (2016), Trouble (2017), Hustlers (2019) and The God Committee (2021).\n\ne recent work includes',
#       'plaidHtml': 'Lovely, Julia (O&#39;Hara) Stiles, of Irish, English and German heritage, was born on March 28, 1981 in New York City, the outgoing daughter and eldest of three children of a Greenwich Village artist mother, Judith Newcomb Stiles, and an elementary school teacher father, John O&#39;Hara.<br/><br/>Encouraged to take modern dance lessons, she was introduced to Shakespeare and theater at an early age. When she was 11, she made her stage debut as a child actress with the experimental off-Broadway La MaMa Theatre. Her passion grew and by the next year was performing professionally and working in commercials. A bright, precocious student, she was seriously considered for the child vampire role of Claudia in <a class="ipc-md-link ipc-md-link--entity" href="/title/tt0110148/?ref_=nm_ov_bio_lk">Interview mit einem Vampir (1994)</a> but lost out in the end to <a class="ipc-md-link ipc-md-link--entity" href="/name/nm0000379/?ref_=nm_ov_bio_lk">Kirsten Dunst</a>. She continued training at New York&#39;s Professional Children&#39;s School and, at 15, made her cinematic bow with <a class="ipc-md-link ipc-md-link--entity" href="/title/tt0116592/?ref_=nm_ov_bio_lk">I Love You, I Love You Not (1996)</a> with <a class="ipc-md-link ipc-md-link--entity" href="/name/nm0000132/?ref_=nm_ov_bio_lk">Claire Danes</a>.<br/><br/>Julia was next featured as the daughter of <a class="ipc-md-link ipc-md-link--entity" href="/name/nm0000148/?ref_=nm_ov_bio_lk">Harrison Ford</a> in <a class="ipc-md-link ipc-md-link--entity" href="/title/tt0118972/?ref_=nm_ov_bio_lk">Vertrauter Feind (1997)</a>, with her breakout role occurring on TV with the hard-hitting mini-movie <a class="ipc-md-link ipc-md-link--entity" href="/title/tt0128072/?ref_=nm_ov_bio_lk">Wie ein Vogel ohne Flügel (1997)</a>, which was produced by <a class="ipc-md-link ipc-md-link--entity" href="/name/nm0001856/?ref_=nm_ov_bio_lk">Oprah Winfrey</a> and dealt with child abuse. Her wish to play Shakespeare was granted threefold with her participation in <a class="ipc-md-link ipc-md-link--entity" href="/title/tt0147800/?ref_=nm_ov_bio_lk">10 Dinge, die ich an Dir hasse (1999)</a>, which was based on the Bard&#39;s &quot;The Taming of The Shrew&quot; and earned her the Chicago Film Critics Award as volatile teen Kat; an updated version of <a class="ipc-md-link ipc-md-link--entity" href="/title/tt0171359/?ref_=nm_ov_bio_lk">Hamlet (2000)</a> which paired her Ophelia with <a class="ipc-md-link ipc-md-link--entity" href="/name/nm0000160/?ref_=nm_ov_bio_lk">Ethan Hawke</a>; and another updated version of &quot;Othello&quot; entitled <a class="ipc-md-link ipc-md-link--entity" href="/title/tt0184791/?ref_=nm_ov_bio_lk">O - Vertrauen, Verführung, Verrat (2001)</a>, which involved her high school character of Desi (Desdemona) in a mixed romantic relationship with African-American <a class="ipc-md-link ipc-md-link--entity" href="/name/nm0001616/?ref_=nm_ov_bio_lk">Mekhi Phifer</a>. The violent-edged film, made in 1998, was not released until three years later due to the Colorado shootings at Columbine High School.<br/><br/>In addition, Julia later portrayed Viola off-Broadway in a Shakespeare-in-the-Park production of &quot;Twelfth Night&quot; in 2002. She temporarily interrupted her career after deciding to enroll at Columbia University in 2000, where she earned a degree in English. Stiles has also returned to the stage, appearing in <a class="ipc-md-link ipc-md-link--entity" href="/name/nm0000519/?ref_=nm_ov_bio_lk">David Mamet</a>&#39;s &quot;Oleanna&quot; in London, a role she would reprise on Broadway in 2009, opposite <a class="ipc-md-link ipc-md-link--entity" href="/name/nm0000597/?ref_=nm_ov_bio_lk">Bill Pullman</a> and directed by <a class="ipc-md-link ipc-md-link--entity" href="/name/nm2833903/?ref_=nm_ov_bio_lk">Doug Hughes</a>.<br/><br/>Moving into mainstream roles by the millennium, Julia took on a role that would carry her through the decade, co-starring with <a class="ipc-md-lin ...
#       '__typename': 'Markdown'},
#      '__typename': 'NameBio'},
#     'primaryProfessions': [{'category': {'text': 'Actress',
#        '__typename': 'CreditCategory'},
#       '__typename': 'PrimaryProfession'},
#      {'category': {'text': 'Producer', '__typename': 'CreditCategory'},
#       '__typename': 'PrimaryProfession'},
#      {'category': {'text': 'Director', '__typename': 'CreditCategory'},
#       '__typename': 'PrimaryProfession'}],
#     'professions': [{'profession': {'text': 'Actress',
#        '__typename': 'DisplayableProfession'},
#       '__typename': 'NameProfession'},
#      {'profession': {'text': 'Producer',
#        '__typename': 'DisplayableProfession'},
#       '__typename': 'NameProfession'},
#      {'profession': {'text': 'Director',
#        '__typename': 'DisplayableProfession'},
#       '__typename': 'NameProfession'}],
#     'birthDate': {'displayableProperty': {'value': {'plainText': 'March 28, 1981',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableDateProperty'},
#      'date': '1981-03-28',
#      'dateComponents': {'day': 28,
#       'month': 3,
#       'year': 1981,
#       'isBCE': False,
#       '__typename': 'DateComponents'},
#      '__typename': 'DisplayableDate'},
#     'deathDate': None,
#     'deathStatus': 'ALIVE',
#     'meterRanking': {'currentRank': 554,
#      'rankChange': {'changeDirection': 'UP',
#       'difference': 186,
#       '__typename': 'MeterRankChange'},
#      '__typename': 'NameMeterRanking'},
#     'subNavBio': {'id': 'mb0174644', '__typename': 'NameBio'},
#     'subNavTrivia': {'total': 34, '__typename': 'NameTriviaConnection'},
#     'subNavAwardNominations': {'total': 34,
#      '__typename': 'AwardNominationConnection'},
#     'subNavFaqs': {'total': 0, '__typename': 'AlexaQuestionConnection'},
#     'videos': {'total': 75, '__typename': 'VideoConnection'},
#     'primaryVideos': {'edges': [{'node': {'id': 'vi3064908057',
#         'createdDate': '2024-11-11T15:18:57Z',
#         'isMature': False,
#         'runtime': {'value': 109, '__typename': 'VideoRuntime'},
#         'name': {'value': 'Official Trailer',
#          'language': 'en',
#          '__typename': 'LocalizedString'},
#         'description': {'value': '',
#          'language': 'en',
#          '__typename': 'LocalizedString'},
#         'timedTextTracks': [],
#         'recommendedTimedTextTrack': None,
#         'thumbnail': {'url': 'https://m.media-amazon.com/images/M/MV5BMWZkZWNiMTItNWVmYy00NTY1LTlhN2EtNTBiZWVjZDA0MWIwXkEyXkFqcGdeQXRyYW5zY29kZS13b3JrZmxvdw@@._V1_.jpg',
#          'height': 360,
#          'width': 640,
#          '__typename': 'Thumbnail'},
#         'primaryTitle': {'id': 'tt27799825',
#          'titleText': {'text': 'Chosen Family', '__typename': 'TitleText'},
#          'originalTitleText': {'text': 'Chosen Family',
#           '__typename': 'TitleText'},
#          'releaseYear': {'year': 2024,
#           '__typename': 'YearRange',
#           'endYear': None},
#          '__typename': 'Title',
#          'titleType': {'canHaveEpisodes': False, '__typename': 'TitleType'}},
#         'playbackURLs': [{'displayName': {'value': '480p',
#            'language': 'en-US',
#            '__typename': 'LocalizedString'},
#           'videoMimeType': 'MP4',
#           'videoDefinition': 'DEF_480p',
#           'url': 'https://imdb-video.media-imdb.com/vi3064908057/1434659607842-pgv4ql-1731338337720.mp4?Expires=1742452968&Signature=ofAx-vvhvSXxaAaPK-rTq7hzA6XBmLjeJZCs8cxuIH-nwDTGTBygqtQPjMXyE4s1KSnSZYCfAW0wGIgggXxuq7bXdhuDwff1PbcYluoiO-dqx~JDzp2LwL0Vf~fYfc-OEvB2xSZE9pmiFG48Wuw6zIBYgcgpacoDoW6Fuh-xcBIz0h-ua31lK67QeimcBIFXDAU60Xp~wf90QgWSjMX1waOfYnKeWvUr0ak9aQkdg3HJghPQvPWCfqNeOZrj0rzjhDzTkxJRHcghPk2nU78bx4Lc5sfP6NMWrKnAT8Gfb1AR~z01h5qoX6x7chKuawb29Dhl03msREqSYAjUd8r5tA__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA',
#           '__typename': 'PlaybackURL'},
#          {'displayName': {'value': 'SD',
#            'language': 'en-US',
#            '__typename': 'LocalizedString'},
#           'videoMimeType': 'MP4',
#           'videoDefinition': 'DEF_SD',
#           'url': 'https://imdb-video.media-imdb.com/vi3064908057/1434659454657-dx9ykf-1731338337720.mp4?Expires=1742452968&Signature=MsgzU44h9aNrIJ~z8n8uNs2YTxSXhuRmZKpVbuuf3Z1jMkbsJiXM0rPIn-UeAdooAXNZ4cuJCUheaK1cDz0451kOG4E5Dzc6xW0dJ8-zxhlyMuJla7KhVUX3P9B4HqSuVlKtkq7mdtOXM1JgMck95q4vzAaPaKvxvkbMmXivCs3wq2McWIEu12K91wU5zb9hCZjCADzmRlaZCDS61El9fTOm-nEjQXH7~xg6-MBlp4TYjTZyrowqSEsDNYbJte~mAqBo70Ao43uweOudEhXEBmkL3gStWP~EbkPX6aQBl8AL~pxU9EUpQeetBzfSSSxFK4IX43GV~-O0KULvyEz0PQ__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA',
#           '__typename': 'PlaybackURL'}],
#         'contentType': {'id': 'amzn1.imdb.video.contenttype.trailer',
#          'displayName': {'value': 'Trailer', '__typename': 'LocalizedString'},
#          '__typename': 'VideoContentType'},
#         'previewURLs': [{'displayName': {'value': 'AUTO',
#            'language': 'en-US',
#            '__typename': 'LocalizedString'},
#           'videoMimeType': 'M3U8',
#           'videoDefinition': 'DEF_AUTO',
# ...
#       '__typename': 'Markdown'},
#      '__typename': 'NameBio'},
#     'primaryProfessions': [{'category': {'text': 'Actor',
#        '__typename': 'CreditCategory'},
#       '__typename': 'PrimaryProfession'},
#      {'category': {'text': 'Producer', '__typename': 'CreditCategory'},
#       '__typename': 'PrimaryProfession'},
#      {'category': {'text': 'Make-Up Department',
#        '__typename': 'CreditCategory'},
#       '__typename': 'PrimaryProfession'}],
#     'professions': [{'profession': {'text': 'Actor',
#        '__typename': 'DisplayableProfession'},
#       '__typename': 'NameProfession'},
#      {'profession': {'text': 'Producer',
#        '__typename': 'DisplayableProfession'},
#       '__typename': 'NameProfession'},
#      {'profession': {'text': 'Make-Up Department',
#        '__typename': 'DisplayableProfession'},
#       '__typename': 'NameProfession'}],
#     'birthDate': {'displayableProperty': {'value': {'plainText': 'December 16, 1955',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableDateProperty'},
#      'date': '1955-12-16',
#      'dateComponents': {'day': 16,
#       'month': 12,
#       'year': 1955,
#       'isBCE': False,
#       '__typename': 'DateComponents'},
#      '__typename': 'DisplayableDate'},
#     'deathDate': None,
#     'deathStatus': 'ALIVE',
#     'meterRanking': {'currentRank': 2994,
#      'rankChange': {'changeDirection': 'UP',
#       'difference': 233,
#       '__typename': 'MeterRankChange'},
#      '__typename': 'NameMeterRanking'},
#     'subNavBio': {'id': 'mb0002987', '__typename': 'NameBio'},
#     'subNavTrivia': {'total': 14, '__typename': 'NameTriviaConnection'},
#     'subNavAwardNominations': {'total': 30,
#      '__typename': 'AwardNominationConnection'},
#     'subNavFaqs': {'total': 11, '__typename': 'AlexaQuestionConnection'},
#     'videos': {'total': 44, '__typename': 'VideoConnection'},
#     'primaryVideos': {'edges': [{'node': {'id': 'vi1439483161',
#         'createdDate': '2023-01-18T22:39:05Z',
#         'isMature': False,
#         'runtime': {'value': 118, '__typename': 'VideoRuntime'},
#         'name': {'value': 'Official Trailer',
#          'language': 'en',
#          '__typename': 'LocalizedString'},
#         'description': {'value': 'In the midst of a global pandemic an actor who enters an audition must pass a series of tests in order to keep those around him alive.',
#          'language': 'en',
#          '__typename': 'LocalizedString'},
#         'timedTextTracks': [],
#         'recommendedTimedTextTrack': None,
#         'thumbnail': {'url': 'https://m.media-amazon.com/images/M/MV5BYWI5NjFjMjctNGFlMi00MDI5LTg3YjktN2U2YWNjNWNjYWRjXkEyXkFqcGdeQWRpZWdtb25n._V1_.jpg',
#          'height': 1080,
#          'width': 1920,
#          '__typename': 'Thumbnail'},
#         'primaryTitle': {'id': 'tt13160874',
#          'titleText': {'text': 'The Audition', '__typename': 'TitleText'},
#          'originalTitleText': {'text': 'The Audition',
#           '__typename': 'TitleText'},
#          'releaseYear': {'year': 2022,
#           '__typename': 'YearRange',
#           'endYear': None},
#          '__typename': 'Title',
#          'titleType': {'canHaveEpisodes': False, '__typename': 'TitleType'}},
#         'playbackURLs': [{'displayName': {'value': '480p',
#            'language': 'en-US',
#            '__typename': 'LocalizedString'},
#           'videoMimeType': 'MP4',
#           'videoDefinition': 'DEF_480p',
#           'url': 'https://imdb-video.media-imdb.com/vi1439483161/1434659607842-pgv4ql-1674081545879.mp4?Expires=1742453090&Signature=VDt-1wrs0kgy61zMqdUAfBbn1VKUbsJS5Fm5THwLGiA50~OfVIw7uEhfwNMgvmrJ53i~F9d1Ss7lWDdHgSoLCyelgN~cSmrj4EWQ3ByOoBuRHoAFuo54swePAfp~ChHX3Olbl6wFpqXv9rviphJC9Jc5BnWzPcJzd-4E4cWZTKLkJcuw9Do1LyeL47LZLqibsmwtdCM~2W39tffaqnlyT4YS6699kMG7xBnkR4LLb8X3BglHjB2DFRBh-BPTE5Gp9kIZ-NvhUTpIJppAOcQLFlkEpSxkIB9sJ8YRBlPEhpy-4QwvhW15KpwoITF9VGjWKpScagTWtWCQgkCUe4QOdA__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA',
#           '__typename': 'PlaybackURL'},
#          {'displayName': {'value': 'SD',
#            'language': 'en-US',
#            '__typename': 'LocalizedString'},
#           'videoMimeType': 'MP4',
#           'videoDefinition': 'DEF_SD',
#           'url': 'https://imdb-video.media-imdb.com/vi1439483161/1434659454657-dx9ykf-1674081545879.mp4?Expires=1742453090&Signature=P-WmXMO2YkYektC-pbLUNG2BYXV3ZRwO50qR5c41vfklJil-OYutJ6XFKzMeZzVYoayzImYsbuxoE5~pD~wI79vplUt1Zf3ogyCUN-YiZSUwQMq9K4kqXIPf9voCsVuUZa8XkcNlAGa1-xHxUoMiRL0VjHvd8kxOtGZzbztjwd5kjN1x87G9KSQxrgzQfLk-3LIjcQSm-5Sxw3sFmUnvCuiEbMpJ6WggJOvsRQkTsTZmBiW5GdZwytE9hLkMdtT9EunGsQ7lYbzD7ocNANF5lC7hj1NWLge85SUC~qzl~PAp9YfmNXLgRYm09V6ERV1Z9h5RwJ~8Wo1LDu2XMcoyNg__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA',
#           '__typename': 'PlaybackURL'}],
#         'contentType': {'id': 'amzn1.imdb.video.contenttype.trailer',
#          'displayName': {'value': 'Trailer', '__typename': 'LocalizedString'},
#          '__typename': 'VideoContentType'},
#         'previewURLs': [{'displayName': {'value': 'AUTO',
#            'language': 'en-US',
#            '__typename': 'LocalizedString'},
#           'videoMimeType': 'M3U8',
#           'videoDefinition': 'DEF_AUTO',
#           'url': 'https://imdb-video.media-imdb.com/vi1439483161/hls-preview-10ec06dd-6dfd-4e35-8936-0ab47b091d82.m3u8?Expires=1742453090&Signature=GfMw34ztDDX4mrD96z7Zrzq2iIpJwqA4g81yBZjK6ZxfBm-coCqTd3QvfHRyWniApY1~5e9VmXOw55YLHMQv-ouVuiRHje0QNoonBBu-rRu-ZQuWzYq-OGv~zy90-zqNyKmQINf2X9gvgJBlP6U4djkEqpmKO~WZ77LiGeiUo~yNZNHR64Tze~kWt1EKOhov98bUjJuGKnKKAdvFuyoxJTIDNGfc64DjXjXQNDmRtPNIhFTSXkRP9V7v6R7YQDeMiOadh2Jmz~CPbuYiB3Mdm4-mruqL6QmjOTsAx~ZRdg3gahBYZbICMVbiUtghuTQzeqLxnweGqlTtPvnKzHltRw__&Key-Pair-Id=APKAIFLZBVQZ24NQH3KA',
#           '__typename': 'PlaybackURL'}],
#         '__typename': 'Video'},
#        '__typename': 'VideoEdge'}],
#      '__typename': 'VideoConnection'},
#     '__typename': 'Name'}}},
#  ("I just want to tell you both good luck. We're all counting on you._The life of everyone on board depends upon just one thing: finding someone back there who can not only fly this plane, but who didn't have fish for dinner._Extremely serious. It starts with a slight fever and dryness of the throat. When the virus penetrates the red blood cells, the victim becomes dizzy, begins to experience an itchy rash, then the poison goes to work on the central nervous system, severe muscle spasms followed by the inevitable grueling.  At this point, the entire digestive system collapses accompanied by uncontrollable flatulence  Until finally, the poor bastard is reduced to a quivering wasted piece of jelly.",
#   'nm0000558'): {'status': 'ok',
#   'request_id': '7cc5b125-5136-423b-b27d-7e0dd5f10508',
#   'message': None,
#   'data': {'result': {'id': 'nm0000558',
#     'nameText': {'text': 'Leslie Nielsen', '__typename': 'NameText'},
#     'searchIndexing': {'disableIndexing': False,
#      '__typename': 'NameSearchIndexing'},
#     'disambiguator': {'text': 'I', '__typename': 'Disambiguation'},
#     'knownFor': {'edges': [{'node': {'title': {'titleText': {'text': 'Die unglaubliche Reise in einem verrückten Flugzeug',
#           '__typename': 'TitleText'},
#          '__typename': 'Title'},
#         'summary': {'principalCategory': {'text': 'Actor',
#           '__typename': 'CreditCategory'},
#          '__typename': 'NameKnownForSummary'},
#         '__typename': 'NameKnownFor'},
#        '__typename': 'NameKnownForEdge'},
#       {'node': {'title': {'titleText': {'text': 'Die nackte Kanone 2 1/2',
#           '__typename': 'TitleText'},
#          '__typename': 'Title'},
#         'summary': {'principalCategory': {'text': 'Actor',
#           '__typename': 'CreditCategory'},
#          '__typename': 'NameKnownForSummary'},
#         '__typename': 'NameKnownFor'},
#        '__typename': 'NameKnownForEdge'},
#       {'node': {'title': {'titleText': {'text': 'Die nackte Kanone',
#           '__typename': 'TitleText'},
#          '__typename': 'Title'},
#         'summary': {'principalCategory': {'text': 'Actor',
#           '__typename': 'CreditCategory'},
#          '__typename': 'NameKnownForSummary'},
#         '__typename': 'NameKnownFor'},
#        '__typename': 'NameKnownForEdge'}],
#      '__typename': 'NameKnownForConnection'},
#     'images': {'total': 298,
#      'edges': [{'node': {'id': 'rm753358337', '__typename': 'Image'},
#        '__typename': 'ImageEdge'}],
#      '__typename': 'ImageConnection'},
#     'primaryImage': {'id': 'rm2194643712',
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTI3MTE1NjM4N15BMl5BanBnXkFtZTYwNzI3MTI0._V1_.jpg',
#      'height': 400,
#      'width': 267,
#      'caption': {'plainText': 'Leslie Nielsen', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'meta': {'canonicalId': 'nm0000558',
#      'publicationStatus': 'PUBLISHED',
#      '__typename': 'NameMeta'},
#     'bio': {'text': {'plainText': "Leslie William Nielsen was born in Regina, Saskatchewan, and raised in Tulita (formerly Fort Norman), Northwest Territories. His mother, Mabel Elizabeth (Davies), was Welsh. His father, Ingvard Eversen Nielsen, was a Danish-born Mountie and a strict disciplinarian. Leslie studied at the Academy of Radio Arts in Toronto before moving on to New York's Neighborhood Playhouse. His acting career started at a much earlier age when he was forced to lie to his father in order to avoid severe punishment. Leslie starred in over fifty films and many more television films. One of his two brothers became the Deputy Prime Minister of Canada. On October 10, 2002, he was appointed Officer of the Order of Canada (OC) in recognition of his contributions to the film and television industries. On November 28, 2010, Leslie Nielsen died at age 84 of pneumonia and was buried at Evergreen Cemetery in Fort Lauderdale, Florida.",
#       'plaidHtml': 'Leslie William Nielsen was born in Regina, Saskatchewan, and raised in Tulita (formerly Fort Norman), Northwest Territories. His mother, Mabel Elizabeth (Davies), was Welsh. His father, Ingvard Eversen Nielsen, was a Danish-born Mountie and a strict disciplinarian. Leslie studied at the Academy of Radio Arts in Toronto before moving on to New York&#39;s Neighborhood Playhouse. His acting career started at a much earlier age when he was forced to lie to his father in order to avoid severe punishment. Leslie starred in over fifty films and many more television films. One of his two brothers became the Deputy Prime Minister of Canada. On October 10, 2002, he was appointed Officer of the Order of Canada (OC) in recognition of his contributions to the film and television industries. On November 28, 2010, Leslie Nielsen died at age 84 of pneumonia and was buried at Evergreen Cemetery in Fort Lauderdale, Florida.',
#       '__typename': 'Markdown'},
#      '__typename': 'NameBio'},
#     'primaryProfessions': [{'category': {'text': 'Actor',
#        '__typename': 'CreditCategory'},
#       '__typename': 'PrimaryProfession'},
#      {'category': {'text': 'Producer', '__typename': 'CreditCategory'},
#       '__typename': 'PrimaryProfession'},
#      {'category': {'text': 'Writer', '__typename': 'CreditCategory'},
#       '__typename': 'PrimaryProfession'}],
#     'professions': [{'profession': {'text': 'Actor',
#        '__typename': 'DisplayableProfession'},
#       '__typename': 'NameProfession'},
#      {'profession': {'text': 'Producer',
#        '__typename': 'DisplayableProfession'},
#       '__typename': 'NameProfession'},
#      {'profession': {'text': 'Writer', '__typename': 'DisplayableProfession'},
#       '__typename': 'NameProfession'}],
#     'birthDate': {'displayableProperty': {'value': {'plainText': 'February 11, 1926',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableDateProperty'},
#      'date': '1926-02-11',
#      'dateComponents': {'day': 11,
#       'month': 2,
#       'year': 1926,
#       'isBCE': False,
#       '__typename': 'DateComponents'},
#      '__typename': 'DisplayableDate'},
#     'deathDate': {'displayableProperty': {'value': {'plainText': 'November 28, 2010',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableDateProperty'},
#      'date': '2010-11-28',
#      'dateComponents': {'day': 28,
#       'month': 11,
#       'year': 2010,
#       '__typename': 'DateComponents'},
#      '__typename': 'DisplayableDate'},
#     'deathStatus': 'DEAD',
#     'meterRanking': {'currentRank': 1594,
#      'rankChange': {'changeDirection': 'UP',
#       'difference': 399,
#       '__typename': 'MeterRankChange'},
#      '__typename': 'NameMeterRanking'},
#     'subNavBio': {'id': 'mb0026163', '__typename': 'NameBio'},
#     'subNavTrivia': {'total': 30, '__typename': 'NameTriviaConnection'},
#     'subNavAwardNominations': {'total': 12,
#      '__typename': 'AwardNominationConnection'},
#     'subNavFaqs': {'total': 0, '__typename': 'AlexaQuestionConnection'},
#     'videos': {'total': 32, '__typename': 'VideoConnection'},
#     'primaryVideos': {'edges': [{'node': {'id': 'vi1593246233',
#         'createdDate': '2009-06-16T05:22:06Z',
#         'isMature': False,
#         'runtime': {'value': 15, '__typename': 'VideoRuntime'},
#         'name': {'value': 'The Force',
#          'language': 'eng',
#          '__typename': 'LocalizedString'},
#         'description': {'value': 'Each episode of The Force reenacts a true story sourced directly from Royal Canadian Mounted Police case files.',
#          'language': 'eng',
#          '__typename': 'LocalizedString'},
#         'timedTextTracks': [],
#         'recommendedTimedTextTrack': None,
#         'thumbnail': {'url': 'https://m.media-amazon.com/images/M/MV5BMTcyODMxMzg1Ml5BMl5BanBnXkFtZTcwNzA3NjQ2Mg@@._V1_.jpg',
#          'height': 480,
#          'width': 640,
#          '__typename': 'Thumbnail'},
#         'primaryTitle': {'id': 'tt1442582',
#          'titleText': {'text': 'The Force', '__typename': 'TitleText'},
#          'originalTitleText': {'text': 'The Force', '__typename': 'TitleText'},
#          'releaseYear': {'year': 2009,
#           '__typename': 'YearRange',
#           'endYear': None},
#          '__typename': 'Title',
#          'titleType': {'canHaveEpisodes': False, '__typename': 'TitleType'}},
#         'playbackURLs': [{'displayName': {'value': '480p',
#            'language': 'en-US',
#            '__typename': 'LocalizedString'},
#           'videoMimeType': 'MP4',
#           'videoDefinition': 'DEF_480p',
#           'url': 'https://imdb-video-wab.media-imdb.com/vi1593246233/MV5BNzgwMDcwNTM1Nl5BMTFeQW1wNF5BbWU4MDUxMzAzOTIx.mp4?Expires=1742452926&Signature=gSVzZrr0gMIos967zyeigDDQBEmywmzBBIwsiUC-xd9~9qmpu3n-rkZtjQB65piYWEaC~VZt4xznXrVpRLlE2DihqKRzZsaJQqtcoIjfeee16ncJSgiFFNjhLVokjgsa0LU5IZJf5cC9CqVhKgJuBZVD-LaTebOUvTJJZlMoq4yOc32Adwe~anH6mJs2n8TliAAAKmJwTe9~fcQDNRyb6JQEzSSmFz-ZZcAgOF1tvAVzoVzipDDUz1RELGYefGSCTvprhlHmm2VNnphViUBpEihHRj-uIJwCHxe48C7fQSgGpwZGjgdNSBocQcWbRhKastfRDab8~lbJNc19TLwCag__&Key-Pair-Id=APKAJLOTGGE6P3RA3PTA',
#           '__typename': 'PlaybackURL'},
#          {'displayName': {'value': 'SD',
#            'language': 'en-US',
#            '__typename': 'LocalizedString'},
#           'videoMimeType': 'MP4',
#           'videoDefinition': 'DEF_SD',
#           'url': 'https://imdb-video-wab.media-imdb.com/vi1593246233/MV5BMTk0MDUxNTQxNl5BMTFeQW1wNF5BbWU4MDU3MzAzOTIx.mp4?Expires=1742452926&Signature=iW4npXaTnWLZ-vwOARrCdlWheaSV6hb7nb4U0x9GtS0-wCH9GHF-OebqWUD3A9F1RG1FH54fKUHJERJo0MXJt7tNVhaiWrEh65PA6BqXoOEJg6CZhzoB7L9HV0KozT8KuzMhJzGLuVPEK53PBC9yazU4GOTKZ96IJQDMtAStoRNbS6rGNSHy1yGU6Bwb5cdGSumILDyTs4OIBJouP2ze5DlkaDsu1HQKYjrNNP8sR4p~R~~TB5l3ObU2~zjjYfCP6jvFnk~pf~xY9vj7GoYmg~lkrSpS7JABw6bqp5qU4Dj5S~uXnvqLidxpyK6s6YU1b2B38o93k2zffQAxp9wacw__&Key-Pair-Id=APKAJLOTGGE6P3RA3PTA',
#           '__typename': 'PlaybackURL'}],
#         'contentType': {'id': 'amzn1.imdb.video.contenttype.trailer',
#          'displayName': {'value': 'Trailer', '__typename': 'LocalizedString'},
#          '__typename': 'VideoContentType'},
#         'previewURLs': [],
#         '__typename': 'Video'},
#        '__typename': 'VideoEdge'}],
#      '__typename': 'VideoConnection'},
#     '__typename': 'Name'}}}}

# %% [markdown]
# Get the date of births and the bios of specific actors

# %%
DOBs = []
bios = []
for actor in actor_jsons:
  if actor in actor_jsons:  # Check if actor is present in actor_jsons
    DOB = get_age(actor_jsons[actor])
    bio = get_bio(actor_jsons[actor])
  else:
    age = "None"  # or any default value for missing age
    bio = "None"  # or any default value for missing bio

  DOBs.append(DOB)
  bios.append(bio)


df_num["actor_DOB"] = DOBs
df_num["actor_bio"] = bios
# Out:
# <ipython-input-41-0f68980ca5b3>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_num["actor_DOB"] = DOBs
# <ipython-input-41-0f68980ca5b3>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_num["actor_bio"] = bios

# %% [markdown]
# This third call is a different endpoint on the first API we called. This is one retrieves a lot of information about the called movies. The information we care about is release date, so we can use that with DOB to calculate age.

# %%
def get_movie_details(movie_id):
  url = f"https://imdb236.p.rapidapi.com/imdb/tt{movie_id}"

  headers = {
	"x-rapidapi-key": "91514d88a9msh6375841cf39c88bp1054afjsn72bc51c76bb4",
	"x-rapidapi-host": "imdb236.p.rapidapi.com"
}

  response = requests.get(url, headers=headers)

  return response.json()

movie_details = {}
for movie in unique_movies:
  id = get_id(movie)
  movie_date = get_movie_details(id)
  movie_details[movie] = movie_date

# %%
#for movie release dates
movies_list = []
for title, details in movie_details.items():
    release_date = details.get("releaseDate", None)  # Get the release date for each movie
    movies_list.append({"title": title, "release_date": release_date})

# %% [markdown]
# This dataframe will be merged with our other dataframe to save requests since there are multiple characters in the same movies in this dataframe.

# %%
#turn to dataframe to be merged
df_movies_list = pd.DataFrame(movies_list)
df_movies_list
# Out:
#                                                 title release_date
# 0                          10 things i hate about you   1999-03-31
# 1                          1492: conquest of paradise   1992-10-09
# 2                                          15 minutes   2001-03-09
# 3                               2001: a space odyssey   1968-05-12
# 4                                                 8mm   1999-02-26
# 5                                   a bucket of blood   1959-10-21
# 6                                  a clockwork orange   1972-02-02
# 7                                      a few good men   1992-12-11
# 8                                  a hard day's night   1964-07-07
# 9                           a nightmare on elm street   1984-11-16
# 10        a nightmare on elm street 3: dream warriors   1987-02-27
# 11      a nightmare on elm street 4: the dream master   1988-08-19
# 12  a nightmare on elm street part 2: freddy's rev...   1985-11-01
# 13         a nightmare on elm street: the dream child   1989-08-11
# 14                                    a perfect world   1993-11-24
# 15                                      a serious man   2009-11-06
# 16                                 a walk to remember   2002-01-25
# 17                                      above the law   1988-04-22
# 18                                     absolute power   1997-02-14
# 19                          ace ventura pet detective   1994-02-04
# 20                                         adaptation   2003-02-14
# 21                                         affliction   1999-02-19
# 22                               after school special   2006-05-25
# 23                                       agnes of god   1985-09-27
# 24                                      air force one   1997-07-25
# 25                                           airplane   1980-07-02

# %%
df_num
# Out:
#     Unnamed: 0                 movie_title   character  \
# 0            0  10 things i hate about you      bianca
# 1            1  10 things i hate about you     cameron
# 2            2  10 things i hate about you        joey
# 3            3  10 things i hate about you         kat
# 4            4  10 things i hate about you     michael
# ..         ...                         ...         ...
# 88          88                  affliction        wade
# 90          90                agnes of god       agnes
# 91          91                agnes of god      martha
# 94          94               air force one       gibbs
# 98          98                    airplane  dr. rumack
#
#                                       memorable_quote                 actor  \
# 0   You're asking me out? That's so cute! What's y...        Larisa Oleynik
# 1   Just 'cause you're beautiful, that doesn't mea...  Joseph Gordon-Levitt
# 2   Watching that bitch violate my car doesn't cou...         Andrew Keegan
# 3   I guess in this society, being male and an ass...          Julia Stiles
# 4                  I have a dick on my face, don't I?       David Krumholtz
# ..                                                ...                   ...
# 88  I think there's some dirty business going on i...            Nick Nolte
# 90                 As much as Mother Miriam loves me?             Meg Tilly
# 91  As much as God loves you_I don't know the mean...            Jane Fonda
# 94           How the hell did they get Air Force One?       Xander Berkeley
# 98  I just want to tell you both good luck. We're ...        Leslie Nielsen
#
#      actor_id      job   actor_DOB  \
# 0   nm0646351  actress  1981-06-07
# 1   nm0330687    actor  1981-02-17
# 2   nm0005080    actor  1979-01-29
# 3   nm0005466  actress  1981-03-28
# 4   nm0472710    actor  1978-05-15
# ..        ...      ...         ...
# 88  nm0000560    actor  1941-02-08
# 90  nm0000672  actress  1960-02-14
# 91  nm0000404  actress  1937-12-21
# 94  nm0075359    actor  1955-12-16
# 98  nm0000558    actor  1926-02-11
#
#                                             actor_bio
# 0   Larisa Oleynik was born in Santa Clara County,...
# 1   Joseph Gordon-Levitt is an actor, filmmaker, a...
# 2   Andrew Keegan was born in Shadow Hills, Califo...
# 3   Lovely, Julia (O'Hara) Stiles, of Irish, Engli...
# 4   David Krumholtz is an American actor and comed...
# ..                                                ...
# 88  Nick Nolte was born in Omaha, Nebraska and beg...
# 90  Meg Tilly was set on being a dancer, and at 17...
# 91  Born in New York City to legendary screen star...
# 94  Xander's father was a painter and his mother a...
# 98  Leslie William Nielsen was born in Regina, Sas...
#
# [62 rows x 9 columns]

# %% [markdown]
# This is one part of the dataframe. We ended up with 29 dataframes that we concatenated together.

# %%
#Repeat steps until filling in entire dataframe
df_num.to_csv(f"df_{num}.csv")

# %% [markdown]
# Finding Actor Ages

# %%
#merge movie with list
df_job_releaseDate = df_num.merge(df_movies_list, left_on="movie_title",
                                  right_on="title")
df_job_releaseDate.drop(columns=["title"], inplace=True)
#replace job titles with genders
df_job_releaseDate["job"] = df_job_releaseDate["job"].replace({"actor": "M",
                                                               "actress": "F"})

# %%
#code to calculate age at time of release
df_job_releaseDate["actor_DOB"] = pd.to_datetime(df_job_releaseDate["actor_DOB"],
                                                 errors='coerce')
df_job_releaseDate["release_date"] = pd.to_datetime(df_job_releaseDate["release_date"],
                                                    errors='coerce')

df_job_releaseDate["age_at_release"] = (df_job_releaseDate["release_date"].dt.year
                                        - df_job_releaseDate["actor_DOB"].dt.year)

df_job_releaseDate
# Out:
#     Unnamed: 0                 movie_title   character  \
# 0            0  10 things i hate about you      bianca
# 1            1  10 things i hate about you     cameron
# 2            2  10 things i hate about you        joey
# 3            3  10 things i hate about you         kat
# 4            4  10 things i hate about you     michael
# ..         ...                         ...         ...
# 57          88                  affliction        wade
# 58          90                agnes of god       agnes
# 59          91                agnes of god      martha
# 60          94               air force one       gibbs
# 61          98                    airplane  dr. rumack
#
#                                       memorable_quote                 actor  \
# 0   You're asking me out? That's so cute! What's y...        Larisa Oleynik
# 1   Just 'cause you're beautiful, that doesn't mea...  Joseph Gordon-Levitt
# 2   Watching that bitch violate my car doesn't cou...         Andrew Keegan
# 3   I guess in this society, being male and an ass...          Julia Stiles
# 4                  I have a dick on my face, don't I?       David Krumholtz
# ..                                                ...                   ...
# 57  I think there's some dirty business going on i...            Nick Nolte
# 58                 As much as Mother Miriam loves me?             Meg Tilly
# 59  As much as God loves you_I don't know the mean...            Jane Fonda
# 60           How the hell did they get Air Force One?       Xander Berkeley
# 61  I just want to tell you both good luck. We're ...        Leslie Nielsen
#
#      actor_id job  actor_DOB  \
# 0   nm0646351   F 1981-06-07
# 1   nm0330687   M 1981-02-17
# 2   nm0005080   M 1979-01-29
# 3   nm0005466   F 1981-03-28
# 4   nm0472710   M 1978-05-15
# ..        ...  ..        ...
# 57  nm0000560   M 1941-02-08
# 58  nm0000672   F 1960-02-14
# 59  nm0000404   F 1937-12-21
# 60  nm0075359   M 1955-12-16
# 61  nm0000558   M 1926-02-11
#
#                                             actor_bio release_date  \
# 0   Larisa Oleynik was born in Santa Clara County,...   1999-03-31
# 1   Joseph Gordon-Levitt is an actor, filmmaker, a...   1999-03-31
# 2   Andrew Keegan was born in Shadow Hills, Califo...   1999-03-31
# 3   Lovely, Julia (O'Hara) Stiles, of Irish, Engli...   1999-03-31
# 4   David Krumholtz is an American actor and comed...   1999-03-31
# ..                                                ...          ...
# 57  Nick Nolte was born in Omaha, Nebraska and beg...   1999-02-19
# 58  Meg Tilly was set on being a dancer, and at 17...   1985-09-27
# 59  Born in New York City to legendary screen star...   1985-09-27
# 60  Xander's father was a painter and his mother a...   1997-07-25
# 61  Leslie William Nielsen was born in Regina, Sas...   1980-07-02
#
#     age_at_release
# 0             18.0
# 1             18.0
# 2             20.0
# 3             18.0
# 4             21.0
# ..             ...
# 57            58.0
# 58            25.0
# 59            48.0
# 60            42.0
# 61            54.0
#
# [62 rows x 11 columns]

# %%
df_job_releaseDate.rename(columns={ "job" : "gender"})
# Out:
#     Unnamed: 0                 movie_title   character  \
# 0            0  10 things i hate about you      bianca
# 1            1  10 things i hate about you     cameron
# 2            2  10 things i hate about you        joey
# 3            3  10 things i hate about you         kat
# 4            4  10 things i hate about you     michael
# ..         ...                         ...         ...
# 57          88                  affliction        wade
# 58          90                agnes of god       agnes
# 59          91                agnes of god      martha
# 60          94               air force one       gibbs
# 61          98                    airplane  dr. rumack
#
#                                       memorable_quote                 actor  \
# 0   You're asking me out? That's so cute! What's y...        Larisa Oleynik
# 1   Just 'cause you're beautiful, that doesn't mea...  Joseph Gordon-Levitt
# 2   Watching that bitch violate my car doesn't cou...         Andrew Keegan
# 3   I guess in this society, being male and an ass...          Julia Stiles
# 4                  I have a dick on my face, don't I?       David Krumholtz
# ..                                                ...                   ...
# 57  I think there's some dirty business going on i...            Nick Nolte
# 58                 As much as Mother Miriam loves me?             Meg Tilly
# 59  As much as God loves you_I don't know the mean...            Jane Fonda
# 60           How the hell did they get Air Force One?       Xander Berkeley
# 61  I just want to tell you both good luck. We're ...        Leslie Nielsen
#
#      actor_id gender  actor_DOB  \
# 0   nm0646351      F 1981-06-07
# 1   nm0330687      M 1981-02-17
# 2   nm0005080      M 1979-01-29
# 3   nm0005466      F 1981-03-28
# 4   nm0472710      M 1978-05-15
# ..        ...    ...        ...
# 57  nm0000560      M 1941-02-08
# 58  nm0000672      F 1960-02-14
# 59  nm0000404      F 1937-12-21
# 60  nm0075359      M 1955-12-16
# 61  nm0000558      M 1926-02-11
#
#                                             actor_bio release_date  \
# 0   Larisa Oleynik was born in Santa Clara County,...   1999-03-31
# 1   Joseph Gordon-Levitt is an actor, filmmaker, a...   1999-03-31
# 2   Andrew Keegan was born in Shadow Hills, Califo...   1999-03-31
# 3   Lovely, Julia (O'Hara) Stiles, of Irish, Engli...   1999-03-31
# 4   David Krumholtz is an American actor and comed...   1999-03-31
# ..                                                ...          ...
# 57  Nick Nolte was born in Omaha, Nebraska and beg...   1999-02-19
# 58  Meg Tilly was set on being a dancer, and at 17...   1985-09-27
# 59  Born in New York City to legendary screen star...   1985-09-27
# 60  Xander's father was a painter and his mother a...   1997-07-25
# 61  Leslie William Nielsen was born in Regina, Sas...   1980-07-02
#
#     age_at_release
# 0             18.0
# 1             18.0
# 2             20.0
# 3             18.0
# 4             21.0
# ..             ...
# 57            58.0
# 58            25.0
# 59            48.0
# 60            42.0
# 61            54.0
#
# [62 rows x 11 columns]

# %% [markdown]
# Generally, movies take about a year after filming before being released in theaters, so we wanted to take in account the estimate of when the actor/actress said the line to see if there were any problematic trends.

# %%
#column for approx age while filming, most movies take about a year after filming to come out
df_job_releaseDate["approx_age_filming"] = df_job_releaseDate["age_at_release"] - 1

# %% [markdown]
# Cleaning the data

# %%
df_cleaned = df_job_releaseDate.dropna(subset=["release_date", "actor_DOB"])
missing_values_after = df_cleaned[["release_date", "actor_DOB"]].isna().sum()

# %% [markdown]
# Wanted an easy way to know how many quotes are said by one person. Not gonna be as helpful since we are going to separate the data by individual quotes instead of characters

# %%
df_cleaned["quote_count"] = df_cleaned["memorable_quote"].str.count("_") + 1
# Out:
# <ipython-input-55-898c7fb7e3ce>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned["quote_count"] = df_cleaned["memorable_quote"].str.count("_") + 1

# %%
#repeat for until all data is recorded
df_cleaned
# Out:
#     Unnamed: 0                                        movie_title  \
# 0            0                         10 things i hate about you
# 1            1                         10 things i hate about you
# 2            2                         10 things i hate about you
# 3            3                         10 things i hate about you
# 4            4                         10 things i hate about you
# 5            5                         10 things i hate about you
# 6            6                         10 things i hate about you
# 7            7                         1492: conquest of paradise
# 8            8                                         15 minutes
# 9           11                                                8mm
# 10          12                                  a bucket of blood
# 11          13                                  a bucket of blood
# 12          14                                 a clockwork orange
# 13          15                                 a clockwork orange
# 14          19                                     a few good men
# 15          20                                     a few good men
# 16          21                                     a few good men
# 17          22                                 a hard day's night
# 18          23                                 a hard day's night
# 19          24                                 a hard day's night
# 20          25                                 a hard day's night
# 21          26                                 a hard day's night
# 22          27                          a nightmare on elm street
# 23          28                          a nightmare on elm street
# 24          29                          a nightmare on elm street
# 25          30                          a nightmare on elm street
# 28          35        a nightmare on elm street 3: dream warriors
# 29          38        a nightmare on elm street 3: dream warriors
# 30          39        a nightmare on elm street 3: dream warriors
# 32          42        a nightmare on elm street 3: dream warriors
# 33          45      a nightmare on elm street 4: the dream master
# 34          51  a nightmare on elm street part 2: freddy's rev...
# 35          52  a nightmare on elm street part 2: freddy's rev...
# 36          54  a nightmare on elm street part 2: freddy's rev...
# 38          57         a nightmare on elm street: the dream child
# 39          58         a nightmare on elm street: the dream child
# 40          61                                    a perfect world
# 41          63                                      a serious man
# 42          65                                 a walk to remember
# 43          66                                 a walk to remember
# 44          67                                      above the law
# 45          68                                     absolute power
# 46          71                                     absolute power
# 47          72                                     absolute power
# 48          74                                     absolute power
# 49          75                                     absolute power
# 50          76                          ace ventura pet detective
# 52          80                                         adaptation
# 53          82                                         adaptation
# 54          83                                         adaptation
# 55          84                                         adaptation
# 56          85                                         affliction
# 57          88                                         affliction
# 58          90                                       agnes of god
# 59          91                                       agnes of god
# 60          94                                      air force one
# 61          98                                           airplane
#
#           character                                    memorable_quote  \
# 0            bianca  You're asking me out? That's so cute! What's y...
# 1           cameron  Just 'cause you're beautiful, that doesn't mea...
# 2              joey  Watching that bitch violate my car doesn't cou...
# 3               kat  I guess in this society, being male and an ass...
# 4           michael                 I have a dick on my face, don't I?
# 5           patrick  Who knocked up your sister?_I was watching you...
# 6            walter  You're 18, you don't know what you want. And y...
# 7          fernando  Of all the words my father wrote - and there w...
# 8              emil  I can kill you - I'm insane._I love America. N...
# 9               max  Oh, he's a lover, man... definitely loves what...
# 10          maxwell  Where are John, Joe, Jake, Jim, jerk? Dead, de...
# 11           walter  I didn't mean to hurt you, Lou. But if you'd h...
# 12             alex  One thing I could never stand was to see a fil...
# 13      chief guard  Pick that up and put it down properly!_Are you...
# 14           jessep  You see Danny, I can deal with the bullets, an...
# 15           kaffee  Why does a Lieutenant Junior Grade with nine m...
# 16              sam  "I strenuously object?" Is that how it works? ...
# 17         director  You don't know what this means to me. If you h...
# 18           george  He's very fussy about his drums, you know. The...
# 19             john  He's sex obsessed! The older generation's lead...
# 20             norm  God knows what you've unleashed on the unsuspe...
# 21            ringo  I'm going out parading before it's too late!_T...
# 22             glen  I'm going to punch out your ugly lights, whoev...
# 23          krueger                     I'm your boyfriend now, Nancy.
# 24            nancy  One, two, Freddy's coming for you. / Three, fo...
# 25              rod  Guys can have nightmares too ya know. Ya ain't...
# 28          kristen  You stupid bitch, you're killing us... YOU'RE ...
# 29            nancy  It's now or never. I'm not gonna kid you, this...
# 30             neil                       My God. You were his mother.
# 32             will  In my dreams I can walk. My legs are strong. I...
# 33           freddy  I wanna draw some blood!_You can check in, but...
# 34           freddy  Go ahead, Jesse. Try it on for size._He can't ...
# 35            grady  Schneider got wasted last night. He must have ...
# 36             lisa  Fight him. You are not afraid of him! He doesn...
# 38           freddy  Hey, Danny, better not dream and drive._Kids.....
# 39             mark  Why don't you shut up and let her talk? I mean...
# 40            butch  You know, Phillip, you have a goddamned red, w...
# 41            larry  I feel like the carpet's been yanked out from ...
# 42            jamie  Our love is like the wind... I can't see it, b...
# 43           landon                 All I know is... you're beautiful.
# 44          salvano  This maniac should be wearing a number, not a ...
# 45           burton  Miss Russell, I should've called the police th...
# 46             kate  Do you know what it's like to be the only kid ...
# 47           luther  This person, they... they go in the front door...
# 48             seth  Kate, he's on the run and he's scared. And he'...
# 49  walter sullivan  I'd been married to my Rebecca for forty-seven...
# 50              ace  Warning. Assholes are closer than they appear....
# 52           donald  Okay, well here's the twist. We find out that,...
# 53          kaufman  There are too many ideas and things and people...
# 54          laroche  Look, I'll tell you a story, all right? I once...
# 55           orlean  I suppose I do have one unembarrassed passion....
# 56        lariviere  That's what I love about this small town. Ever...
# 57             wade  I think there's some dirty business going on i...
# 58            agnes                 As much as Mother Miriam loves me?
# 59           martha  As much as God loves you_I don't know the mean...
# 60            gibbs           How the hell did they get Air Force One?
# 61       dr. rumack  I just want to tell you both good luck. We're ...
#
#                    actor   actor_id job  actor_DOB  \
# 0         Larisa Oleynik  nm0646351   F 1981-06-07
# 1   Joseph Gordon-Levitt  nm0330687   M 1981-02-17
# 2          Andrew Keegan  nm0005080   M 1979-01-29
# 3           Julia Stiles  nm0005466   F 1981-03-28
# 4        David Krumholtz  nm0472710   M 1978-05-15
# 5           Heath Ledger  nm0005132   M 1979-04-04
# 6           Larry Miller  nm0588777   M 1953-10-15
# 7             Loren Dean  nm0000363   M 1969-07-31
# 8            Karel Roden  nm0734558   M 1962-05-18
# 9        Joaquin Phoenix  nm0001618   M 1974-10-28
# 10         Julian Burton  nm0123630   M 1932-06-04
# 11           Dick Miller  nm0588241   M 1928-12-25
# 12      Malcolm McDowell  nm0000532   M 1943-06-13
# 13         Michael Bates  nm0060988   M 1920-12-04
# 14        Jack Nicholson  nm0000197   M 1937-04-22
# 15            Tom Cruise  nm0000129   M 1962-07-03
# 16          Kevin Pollak  nm0001629   M 1957-10-30
# 17       Victor Spinetti  nm0818920   M 1929-09-02
# 18       George Harrison  nm0365600   M 1943-02-25
# 19           John Lennon  nm0006168   M 1940-10-09
# 20     Norman Rossington  nm0744395   M 1928-12-24
# 21           Ringo Starr  nm0823592   M 1940-07-07
# 22           Johnny Depp  nm0000136   M 1963-06-09
# 23        Robert Englund  nm0000387   M 1947-06-06
# 24    Heather Langenkamp  nm0000486   F 1964-07-17
# 25            Jsu Garcia  nm0006987   M 1963-10-06
# 28     Patricia Arquette  nm0000099   F 1968-04-08
# 29    Heather Langenkamp  nm0000486   F 1964-07-17
# 30          Craig Wasson  nm0913738   M 1954-03-15
# 32            Ira Heiden  nm0373934   M 1966-09-22
# 33        Robert Englund  nm0000387   M 1947-06-06
# 34        Robert Englund  nm0000387   M 1947-06-06
# 35         Robert Rusler  nm0750852   M 1965-09-20
# 36             Kim Myers  nm0616766   F 1966-02-15
# 38        Robert Englund  nm0000387   M 1947-06-06
# 39             Joe Seely  nm0781618   M 1960-02-18
# 40         Kevin Costner  nm0000126   M 1955-01-18
# 41     Michael Stuhlbarg  nm0836121   M 1968-07-05
# 42           Mandy Moore  nm0601553   F 1984-04-10
# 43            Shane West  nm0922342   M 1978-06-10
# 44        Daniel Faraldo  nm0267066   M 1949-11-04
# 45           Scott Glenn  nm0001277   M 1939-01-26
# 46          Laura Linney  nm0001473   F 1964-02-05
# 47        Clint Eastwood  nm0000142   M 1930-05-31
# 48             Ed Harris  nm0000438   M 1950-11-28
# 49         E.G. Marshall  nm0550855   M 1914-06-18
# 50            Jim Carrey  nm0000120   M 1962-01-17
# 52          Nicolas Cage  nm0000115   M 1964-01-07
# 53          Nicolas Cage  nm0000115   M 1964-01-07
# 54          Chris Cooper  nm0177933   M 1951-07-09
# 55          Meryl Streep  nm0000658   F 1949-06-22
# 56        Holmes Osborne  nm0651660   M 1947-11-07
# 57            Nick Nolte  nm0000560   M 1941-02-08
# 58             Meg Tilly  nm0000672   F 1960-02-14
# 59            Jane Fonda  nm0000404   F 1937-12-21
# 60       Xander Berkeley  nm0075359   M 1955-12-16
# 61        Leslie Nielsen  nm0000558   M 1926-02-11
#
#                                             actor_bio release_date  \
# 0   Larisa Oleynik was born in Santa Clara County,...   1999-03-31
# 1   Joseph Gordon-Levitt is an actor, filmmaker, a...   1999-03-31
# 2   Andrew Keegan was born in Shadow Hills, Califo...   1999-03-31
# 3   Lovely, Julia (O'Hara) Stiles, of Irish, Engli...   1999-03-31
# 4   David Krumholtz is an American actor and comed...   1999-03-31
# 5   When hunky, twenty-year-old heart-throb Heath ...   1999-03-31
# 6   Larry Miller was born on 15 October 1953 in Va...   1999-03-31
# 7   Loren Dean was born on 31 July 1969 in Las Veg...   1992-10-09
# 8   Karel Roden is an internationally known actor ...   2001-03-09
# 9   Joaquin Phoenix was born Joaquin Rafael Bottom...   1999-02-26
# 10  Julian Burton was born on 4 June 1932 in Detro...   1959-10-21
# 11  Born in the Bronx, New York to Russian Jewish ...   1959-10-21
# 12  Malcolm John Taylor was born on June 13, 1943 ...   1972-02-02
# 13  Michael Bates was born on 4 December 1920 in J...   1972-02-02
# 14  Jack Nicholson, an American actor, producer, d...   1992-12-11
# 15  In 1976, if you had told fourteen-year-old Fra...   1992-12-11
# 16  Kevin (Elliott) Pollak was born in San Francis...   1992-12-11
# 17  Comic eccentric and gifted raconteur Victor Sp...   1964-07-07
# 18  A master musician, a film producer and actor, ...   1964-07-07
# 19  John Winston (later Ono) Lennon was born on Oc...   1964-07-07
# 20  British character actor Norman Rossington was ...   1964-07-07
# 21  Ringo Starr is a British musician, actor, dire...   1964-07-07
# 22  John Christopher "Johnny" Depp II was born on ...   1984-11-16
# 23  Veteran character actor Robert Englund was bor...   1984-11-16
# 24  Heather Langenkamp was born in Tulsa, Oklahoma...   1984-11-16
# 25  Jsu Garcia, DSS is an actor/director and minis...   1984-11-16
# 28  With her expressive blue eyes, soft, Southern-...   1987-02-27
# 29  Heather Langenkamp was born in Tulsa, Oklahoma...   1987-02-27
# 30  Craig Wasson was born on 15 March 1954 in Onta...   1987-02-27
# 32  Ira Heiden was born on 22 September 1966 in Ne...   1987-02-27
# 33  Veteran character actor Robert Englund was bor...   1988-08-19
# 34  Veteran character actor Robert Englund was bor...   1985-11-01
# 35  Robert Rusler - actor, athlete, writer, and na...   1985-11-01
# 36  Kim Myers was born on 15 February 1966, in Los...   1985-11-01
# 38  Veteran character actor Robert Englund was bor...   1989-08-11
# 39  Joe Seely was born on 18 February 1960 in Los ...   1989-08-11
# 40  Kevin Michael Costner was born on January 18, ...   1993-11-24
# 41  Michael Stewart Stuhlbarg was born in Long Bea...   2009-11-06
# 42  Amanda Leigh Moore was born in Nashua, New Ham...   2002-01-25
# 43  Shane West was born Shannon Bruce Snaith in 19...   2002-01-25
# 44  Daniel Faraldo was born on 4 November 1949 in ...   1988-04-22
# 45  Scott Glenn was born January 26, 1939, in Pitt...   1997-02-14
# 46  Laura Leggett Linney was born in New York City...   1997-02-14
# 47  Clinton Eastwood Jr. was born May 31, 1930 in ...   1997-02-14
# 48  By transforming into his characters and pullin...   1997-02-14
# 49  With over 150 Film and TV appearances to his c...   1997-02-14
# 50  Jim Carrey, Canadian-born and a U.S. citizen s...   1994-02-04
# 52  Nicolas Cage was born Nicolas Kim Coppola in L...   2003-02-14
# 53  Nicolas Cage was born Nicolas Kim Coppola in L...   2003-02-14
# 54  Christopher Walton Cooper was born in Kansas C...   2003-02-14
# 55  Considered by many critics to be the greatest ...   2003-02-14
# 56  Holmes Osborne was born on 7 November 1947 in ...   1999-02-19
# 57  Nick Nolte was born in Omaha, Nebraska and beg...   1999-02-19
# 58  Meg Tilly was set on being a dancer, and at 17...   1985-09-27
# 59  Born in New York City to legendary screen star...   1985-09-27
# 60  Xander's father was a painter and his mother a...   1997-07-25
# 61  Leslie William Nielsen was born in Regina, Sas...   1980-07-02
#
#     age_at_release  approx_age_filming  quote_count
# 0             18.0                17.0            1
# 1             18.0                17.0            3
# 2             20.0                19.0            1
# 3             18.0                17.0            4
# 4             21.0                20.0            1
# 5             20.0                19.0            5
# 6             46.0                45.0            1
# 7             23.0                22.0            1
# 8             39.0                38.0            2
# 9             25.0                24.0            1
# 10            27.0                26.0            2
# 11            31.0                30.0            2
# 12            29.0                28.0           19
# 13            52.0                51.0            3
# 14            55.0                54.0            3
# 15            30.0                29.0            8
# 16            35.0                34.0            1
# 17            35.0                34.0            2
# 18            21.0                20.0            1
# 19            24.0                23.0            4
# 20            36.0                35.0            1
# 21            24.0                23.0            2
# 22            21.0                20.0            3
# 23            37.0                36.0            1
# 24            20.0                19.0            5
# 25            21.0                20.0            2
# 28            19.0                18.0            1
# 29            23.0                22.0            1
# 30            33.0                32.0            1
# 32            21.0                20.0            1
# 33            41.0                40.0           10
# 34            38.0                37.0            3
# 35            20.0                19.0            2
# 36            19.0                18.0            1
# 38            42.0                41.0            3
# 39            29.0                28.0            1
# 40            38.0                37.0            2
# 41            41.0                40.0            2
# 42            18.0                17.0            1
# 43            24.0                23.0            1
# 44            39.0                38.0            1
# 45            58.0                57.0            1
# 46            33.0                32.0            1
# 47            67.0                66.0            3
# 48            47.0                46.0            1
# 49            83.0                82.0            1
# 50            32.0                31.0            7
# 52            39.0                38.0            1
# 53            39.0                38.0            2
# 54            52.0                51.0            1
# 55            54.0                53.0            2
# 56            52.0                51.0            1
# 57            58.0                57.0            3
# 58            25.0                24.0            1
# 59            48.0                47.0            2
# 60            42.0                41.0            1
# 61            54.0                53.0            3

# %%
#ends up with this dataset after repeating
df = pd.read_csv("df_cleaned-4.csv")
